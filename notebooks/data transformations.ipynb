# %%
import os
import zipfile
from concurrent.futures import ThreadPoolExecutor

# %%
import os
import zipfile

def list_csv_files_in_zips(folder_path):
    """
    Lists all CSV files within multiple ZIP archives in a folder.

    Parameters:
    folder_path (str): The path to the folder containing ZIP files.

    Returns:
    dict: A dictionary with ZIP file names as keys and a list of CSV file names as values.
    """
    csv_files = {}
    
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.zip'):
                zip_path = os.path.join(root, file)
                try:
                    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                        csv_list = [name for name in zip_ref.namelist() if name.endswith('.csv')]
                        if csv_list:
                            csv_files[file] = csv_list
                except Exception as e:
                    csv_files[file] = f"An error occurred: {e}"
    
    return csv_files

# Example usage
folder_path = 'path/to/folder'
csv_files = list_csv_files_in_zips(folder_path)
for zip_file, csv_list in csv_files.items():
    print(f"CSV files in {zip_file}:")
    for csv_file in csv_list:
        print(f" - {csv_file}")

# %%
folder_path = '/Users/thusondube/Downloads/itineraries_csv'
csv_files = list_csv_files_in_zips(folder_path)
for zip_file, csv_list in csv_files.items():
    print(f"CSV files in {zip_file}:")
    for csv_file in csv_list:
        print(f" - {csv_file}")
# Out:
# CSV files in OAK_itineraries_cq.zip:
#  - OAK_itineraries_cq.csv
# CSV files in OAK_itineraries_an.zip:
#  - OAK_itineraries_an.csv
# CSV files in OAK_itineraries_bu.zip:
#  - OAK_itineraries_bu.csv
# CSV files in OAK_itineraries_cf.zip:
#  - OAK_itineraries_cf.csv
# CSV files in OAK_itineraries_bb.zip:
#  - OAK_itineraries_bb.csv
# CSV files in OAK_itineraries_ay.zip:
#  - OAK_itineraries_ay.csv
# CSV files in OAK_itineraries_or.zip:
#  - OAK_itineraries_or.csv
# CSV files in OAK_itineraries_li.zip:
#  - OAK_itineraries_li.csv
# CSV files in OAK_itineraries_nv.zip:
#  - OAK_itineraries_nv.csv
# CSV files in OAK_itineraries_mm.zip:
#  - OAK_itineraries_mm.csv
# CSV files in OAK_itineraries_oe.zip:
#  - OAK_itineraries_oe.csv
# CSV files in OAK_itineraries_mz.zip:
#  - OAK_itineraries_mz.csv
# CSV files in OAK_itineraries_na.zip:
#  - OAK_itineraries_na.csv
# CSV files in OAK_itineraries_xl.zip:
#  - OAK_itineraries_xl.csv
# CSV files in OAK_itineraries_yh.zip:
#  - OAK_itineraries_yh.csv
# CSV files in OAK_itineraries_zs.zip:
#  - OAK_itineraries_zs.csv
# CSV files in OAK_itineraries_zd.zip:
#  - OAK_itineraries_zd.csv
# CSV files in OAK_itineraries_wt.zip:
#  - OAK_itineraries_wt.csv
# CSV files in OAK_itineraries_to.zip:
#  - OAK_itineraries_to.csv
# CSV files in OAK_itineraries_vp.zip:
#  - OAK_itineraries_vp.csv
# CSV files in OAK_itineraries_uk.zip:
#  - OAK_itineraries_uk.csv
# CSV files in OAK_itineraries_tx.zip:
#  - OAK_itineraries_tx.csv
# CSV files in OAK_itineraries_wc.zip:
#  - OAK_itineraries_wc.csv
# CSV files in OAK_itineraries_vg.zip:
#  - OAK_itineraries_vg.csv
# CSV files in OAK_itineraries_vf.zip:
#  - OAK_itineraries_vf.csv
# CSV files in OAK_itineraries_wb.zip:
#  - OAK_itineraries_wb.csv
# CSV files in OAK_itineraries_ty.zip:
#  - OAK_itineraries_ty.csv
# CSV files in OAK_itineraries_uj.zip:
#  - OAK_itineraries_uj.csv
# CSV files in OAK_itineraries_vq.zip:
#  - OAK_itineraries_vq.csv
# CSV files in OAK_itineraries_tn.zip:
#  - OAK_itineraries_tn.csv
# CSV files in OAK_itineraries_wu.zip:
#  - OAK_itineraries_wu.csv
# CSV files in OAK_itineraries_ze.zip:
#  - OAK_itineraries_ze.csv
# CSV files in OAK_itineraries_xz.zip:
#  - OAK_itineraries_xz.csv
# CSV files in OAK_itineraries_zr.zip:
#  - OAK_itineraries_zr.csv
# CSV files in OAK_itineraries_yi.zip:
#  - OAK_itineraries_yi.csv
# CSV files in OAK_itineraries_xm.zip:
#  - OAK_itineraries_xm.csv
# CSV files in OAK_itineraries_od.zip:
#  - OAK_itineraries_od.csv
# CSV files in OAK_itineraries_ml.zip:
#  - OAK_itineraries_ml.csv
# CSV files in OAK_itineraries_nw.zip:
#  - OAK_itineraries_nw.csv
# CSV files in OAK_itineraries_lh.zip:
#  - OAK_itineraries_lh.csv
# CSV files in OAK_itineraries_os.zip:
#  - OAK_itineraries_os.csv
# CSV files in OAK_itineraries_ax.zip:
#  - OAK_itineraries_ax.csv
# CSV files in OAK_itineraries_bc.zip:
#  - OAK_itineraries_bc.csv
# CSV files in OAK_itineraries_cg.zip:
#  - OAK_itineraries_cg.csv
# CSV files in OAK_itineraries_bt.zip:
#  - OAK_itineraries_bt.csv
# CSV files in OAK_itineraries_ao.zip:
#  - OAK_itineraries_ao.csv
# CSV files in OAK_itineraries_cp.zip:
#  - OAK_itineraries_cp.csv
# CSV files in OAK_itineraries_am.zip:
#  - OAK_itineraries_am.csv
# CSV files in OAK_itineraries_bv.zip:
#  - OAK_itineraries_bv.csv
# CSV files in OAK_itineraries_cr.zip:
#  - OAK_itineraries_cr.csv
# CSV files in OAK_itineraries_ba.zip:
#  - OAK_itineraries_ba.csv
# CSV files in OAK_itineraries_az.zip:
#  - OAK_itineraries_az.csv
# CSV files in OAK_itineraries_ce.zip:
#  - OAK_itineraries_ce.csv
# CSV files in OAK_itineraries_nu.zip:
#  - OAK_itineraries_nu.csv
# CSV files in OAK_itineraries_mn.zip:
#  - OAK_itineraries_mn.csv
# CSV files in OAK_itineraries_oq.zip:
#  - OAK_itineraries_oq.csv
# CSV files in OAK_itineraries_lj.zip:
#  - OAK_itineraries_lj.csv
# CSV files in OAK_itineraries_my.zip:
#  - OAK_itineraries_my.csv
# CSV files in OAK_itineraries_nb.zip:
#  - OAK_itineraries_nb.csv
# CSV files in OAK_itineraries_of.zip:
#  - OAK_itineraries_of.csv
# CSV files in OAK_itineraries_yk.zip:
#  - OAK_itineraries_yk.csv
# CSV files in OAK_itineraries_zp.zip:
#  - OAK_itineraries_zp.csv
# CSV files in OAK_itineraries_xo.zip:
#  - OAK_itineraries_xo.csv
# CSV files in OAK_itineraries_zg.zip:
#  - OAK_itineraries_zg.csv
# CSV files in OAK_itineraries_xx.zip:
#  - OAK_itineraries_xx.csv
# CSV files in OAK_itineraries_vs.zip:
#  - OAK_itineraries_vs.csv
# CSV files in OAK_itineraries_uh.zip:
#  - OAK_itineraries_uh.csv
# CSV files in OAK_itineraries_ww.zip:
#  - OAK_itineraries_ww.csv
# CSV files in OAK_itineraries_tl.zip:
#  - OAK_itineraries_tl.csv
# CSV files in OAK_itineraries_vd.zip:
#  - OAK_itineraries_vd.csv
# CSV files in OAK_itineraries_wa.zip:
#  - OAK_itineraries_wa.csv
# CSV files in OAK_itineraries_tz.zip:
#  - OAK_itineraries_tz.csv
# CSV files in OAK_itineraries_ve.zip:
#  - OAK_itineraries_ve.csv
# CSV files in OAK_itineraries_tm.zip:
#  - OAK_itineraries_tm.csv
# CSV files in OAK_itineraries_wv.zip:
#  - OAK_itineraries_wv.csv
# CSV files in OAK_itineraries_ui.zip:
#  - OAK_itineraries_ui.csv
# CSV files in OAK_itineraries_vr.zip:
#  - OAK_itineraries_vr.csv
# CSV files in OAK_itineraries_xy.zip:
#  - OAK_itineraries_xy.csv
# CSV files in OAK_itineraries_zf.zip:
#  - OAK_itineraries_zf.csv
# CSV files in OAK_itineraries_xn.zip:
#  - OAK_itineraries_xn.csv
# CSV files in OAK_itineraries_zq.zip:
#  - OAK_itineraries_zq.csv
# CSV files in OAK_itineraries_yj.zip:
#  - OAK_itineraries_yj.csv
# CSV files in OAK_itineraries_og.zip:
#  - OAK_itineraries_og.csv
# CSV files in OAK_itineraries_nc.zip:
#  - OAK_itineraries_nc.csv
# CSV files in OAK_itineraries_mx.zip:
#  - OAK_itineraries_mx.csv
# CSV files in OAK_itineraries_lk.zip:
#  - OAK_itineraries_lk.csv
# CSV files in OAK_itineraries_op.zip:
#  - OAK_itineraries_op.csv
# CSV files in OAK_itineraries_mo.zip:
#  - OAK_itineraries_mo.csv
# CSV files in OAK_itineraries_nt.zip:
#  - OAK_itineraries_nt.csv
# CSV files in OAK_itineraries_cd.zip:
#  - OAK_itineraries_cd.csv
# CSV files in OAK_itineraries_cs.zip:
#  - OAK_itineraries_cs.csv
# CSV files in OAK_itineraries_bw.zip:
#  - OAK_itineraries_bw.csv
# CSV files in OAK_itineraries_al.zip:
#  - OAK_itineraries_al.csv
# CSV files in OAK_itineraries_bd.zip:
#  - OAK_itineraries_bd.csv
# CSV files in OAK_itineraries_ah.zip:
#  - OAK_itineraries_ah.csv
# CSV files in OAK_itineraries_bs.zip:
#  - OAK_itineraries_bs.csv
# CSV files in OAK_itineraries_cw.zip:
#  - OAK_itineraries_cw.csv
# CSV files in OAK_itineraries_ng.zip:
#  - OAK_itineraries_ng.csv
# CSV files in OAK_itineraries_lx.zip:
#  - OAK_itineraries_lx.csv
# CSV files in OAK_itineraries_oc.zip:
#  - OAK_itineraries_oc.csv
# CSV files in OAK_itineraries_np.zip:
#  - OAK_itineraries_np.csv
# CSV files in OAK_itineraries_mk.zip:
#  - OAK_itineraries_mk.csv
# CSV files in OAK_itineraries_ot.zip:
#  - OAK_itineraries_ot.csv
# CSV files in OAK_itineraries_lo.zip:
#  - OAK_itineraries_lo.csv
# CSV files in OAK_itineraries_zb.zip:
#  - OAK_itineraries_zb.csv
# CSV files in OAK_itineraries_yy.zip:
#  - OAK_itineraries_yy.csv
# CSV files in OAK_itineraries_yn.zip:
#  - OAK_itineraries_yn.csv
# CSV files in OAK_itineraries_zu.zip:
#  - OAK_itineraries_zu.csv
# CSV files in OAK_itineraries_xj.zip:
#  - OAK_itineraries_xj.csv
# CSV files in OAK_itineraries_uz.zip:
#  - OAK_itineraries_uz.csv
# CSV files in OAK_itineraries_va.zip:
#  - OAK_itineraries_va.csv
# CSV files in OAK_itineraries_we.zip:
#  - OAK_itineraries_we.csv
# CSV files in OAK_itineraries_vv.zip:
#  - OAK_itineraries_vv.csv
# CSV files in OAK_itineraries_um.zip:
#  - OAK_itineraries_um.csv
# CSV files in OAK_itineraries_wr.zip:
#  - OAK_itineraries_wr.csv
# CSV files in OAK_itineraries_ti.zip:
#  - OAK_itineraries_ti.csv
# CSV files in OAK_itineraries_th.zip:
#  - OAK_itineraries_th.csv
# CSV files in OAK_itineraries_ws.zip:
#  - OAK_itineraries_ws.csv
# CSV files in OAK_itineraries_ul.zip:
#  - OAK_itineraries_ul.csv
# CSV files in OAK_itineraries_vw.zip:
#  - OAK_itineraries_vw.csv
# CSV files in OAK_itineraries_wd.zip:
#  - OAK_itineraries_wd.csv
# CSV files in OAK_itineraries_xk.zip:
#  - OAK_itineraries_xk.csv
# CSV files in OAK_itineraries_zt.zip:
#  - OAK_itineraries_zt.csv
# CSV files in OAK_itineraries_yo.zip:
#  - OAK_itineraries_yo.csv
# CSV files in OAK_itineraries_yx.zip:
#  - OAK_itineraries_yx.csv
# CSV files in OAK_itineraries_zc.zip:
#  - OAK_itineraries_zc.csv
# CSV files in OAK_itineraries_ln.zip:
#  - OAK_itineraries_ln.csv
# CSV files in OAK_itineraries_ou.zip:
#  - OAK_itineraries_ou.csv
# CSV files in OAK_itineraries_mj.zip:
#  - OAK_itineraries_mj.csv
# CSV files in OAK_itineraries_nq.zip:
#  - OAK_itineraries_nq.csv
# CSV files in OAK_itineraries_ob.zip:
#  - OAK_itineraries_ob.csv
# CSV files in OAK_itineraries_ly.zip:
#  - OAK_itineraries_ly.csv
# CSV files in OAK_itineraries_nf.zip:
#  - OAK_itineraries_nf.csv
# CSV files in OAK_itineraries_cv.zip:
#  - OAK_itineraries_cv.csv
# CSV files in OAK_itineraries_br.zip:
#  - OAK_itineraries_br.csv
# CSV files in OAK_itineraries_ai.zip:
#  - OAK_itineraries_ai.csv
# CSV files in OAK_itineraries_ca.zip:
#  - OAK_itineraries_ca.csv
# CSV files in OAK_itineraries_be.zip:
#  - OAK_itineraries_be.csv
# CSV files in OAK_itineraries_cc.zip:
#  - OAK_itineraries_cc.csv
# CSV files in OAK_itineraries_bg.zip:
#  - OAK_itineraries_bg.csv
# CSV files in OAK_itineraries_ct.zip:
#  - OAK_itineraries_ct.csv
# CSV files in OAK_itineraries_ak.zip:
#  - OAK_itineraries_ak.csv
# CSV files in OAK_itineraries_bp.zip:
#  - OAK_itineraries_bp.csv
# CSV files in OAK_itineraries_nd.zip:
#  - OAK_itineraries_nd.csv
# CSV files in OAK_itineraries_ow.zip:
#  - OAK_itineraries_ow.csv
# CSV files in OAK_itineraries_ll.zip:
#  - OAK_itineraries_ll.csv
# CSV files in OAK_itineraries_ns.zip:
#  - OAK_itineraries_ns.csv
# CSV files in OAK_itineraries_mh.zip:
#  - OAK_itineraries_mh.csv
# CSV files in OAK_itineraries_za.zip:
#  - OAK_itineraries_za.csv
# CSV files in OAK_itineraries_yz.zip:
#  - OAK_itineraries_yz.csv
# CSV files in OAK_itineraries_xi.zip:
#  - OAK_itineraries_xi.csv
# CSV files in OAK_itineraries_ym.zip:
#  - OAK_itineraries_ym.csv
# CSV files in OAK_itineraries_zv.zip:
#  - OAK_itineraries_zv.csv
# CSV files in OAK_itineraries_wf.zip:
#  - OAK_itineraries_wf.csv
# CSV files in OAK_itineraries_uy.zip:
#  - OAK_itineraries_uy.csv
# CSV files in OAK_itineraries_vb.zip:
#  - OAK_itineraries_vb.csv
# CSV files in OAK_itineraries_wq.zip:
#  - OAK_itineraries_wq.csv
# CSV files in OAK_itineraries_tj.zip:
#  - OAK_itineraries_tj.csv
# CSV files in OAK_itineraries_vu.zip:
#  - OAK_itineraries_vu.csv
# CSV files in OAK_itineraries_un.zip:
#  - OAK_itineraries_un.csv
# CSV files in OAK_itineraries_uo.zip:
#  - OAK_itineraries_uo.csv
# CSV files in OAK_itineraries_vt.zip:
#  - OAK_itineraries_vt.csv
# CSV files in OAK_itineraries_tk.zip:
#  - OAK_itineraries_tk.csv
# CSV files in OAK_itineraries_wp.zip:
#  - OAK_itineraries_wp.csv
# CSV files in OAK_itineraries_vc.zip:
#  - OAK_itineraries_vc.csv
# CSV files in OAK_itineraries_ux.zip:
#  - OAK_itineraries_ux.csv
# CSV files in OAK_itineraries_wg.zip:
#  - OAK_itineraries_wg.csv
# CSV files in OAK_itineraries_zw.zip:
#  - OAK_itineraries_zw.csv
# CSV files in OAK_itineraries_yl.zip:
#  - OAK_itineraries_yl.csv
# CSV files in OAK_itineraries_xh.zip:
#  - OAK_itineraries_xh.csv
# CSV files in OAK_itineraries_mi.zip:
#  - OAK_itineraries_mi.csv
# CSV files in OAK_itineraries_nr.zip:
#  - OAK_itineraries_nr.csv
# CSV files in OAK_itineraries_lm.zip:
#  - OAK_itineraries_lm.csv
# CSV files in OAK_itineraries_ov.zip:
#  - OAK_itineraries_ov.csv
# CSV files in OAK_itineraries_ne.zip:
#  - OAK_itineraries_ne.csv
# CSV files in OAK_itineraries_oa.zip:
#  - OAK_itineraries_oa.csv
# CSV files in OAK_itineraries_lz.zip:
#  - OAK_itineraries_lz.csv
# CSV files in OAK_itineraries_bq.zip:
#  - OAK_itineraries_bq.csv
# CSV files in OAK_itineraries_aj.zip:
#  - OAK_itineraries_aj.csv
# CSV files in OAK_itineraries_cu.zip:
#  - OAK_itineraries_cu.csv
# CSV files in OAK_itineraries_bf.zip:
#  - OAK_itineraries_bf.csv
# CSV files in OAK_itineraries_cb.zip:
#  - OAK_itineraries_cb.csv
# CSV files in OAK_itineraries_fi.zip:
#  - OAK_itineraries_fi.csv
# CSV files in OAK_itineraries_er.zip:
#  - OAK_itineraries_er.csv
# CSV files in OAK_itineraries_gm.zip:
#  - OAK_itineraries_gm.csv
# CSV files in OAK_itineraries_dv.zip:
#  - OAK_itineraries_dv.csv
# CSV files in OAK_itineraries_ee.zip:
#  - OAK_itineraries_ee.csv
# CSV files in OAK_itineraries_da.zip:
#  - OAK_itineraries_da.csv
# CSV files in OAK_itineraries_gz.zip:
#  - OAK_itineraries_gz.csv
# CSV files in OAK_itineraries_iq.zip:
#  - OAK_itineraries_iq.csv
# CSV files in OAK_itineraries_jj.zip:
#  - OAK_itineraries_jj.csv
# CSV files in OAK_itineraries_hu.zip:
#  - OAK_itineraries_hu.csv
# CSV files in OAK_itineraries_kn.zip:
#  - OAK_itineraries_kn.csv
# CSV files in OAK_itineraries_if.zip:
#  - OAK_itineraries_if.csv
# CSV files in OAK_itineraries_ky.zip:
#  - OAK_itineraries_ky.csv
# CSV files in OAK_itineraries_hb.zip:
#  - OAK_itineraries_hb.csv
# CSV files in OAK_itineraries_qw.zip:
#  - OAK_itineraries_qw.csv
# CSV files in OAK_itineraries_rl.zip:
#  - OAK_itineraries_rl.csv
# CSV files in OAK_itineraries_ps.zip:
#  - OAK_itineraries_ps.csv
# CSV files in OAK_itineraries_sh.zip:
#  - OAK_itineraries_sh.csv
# CSV files in OAK_itineraries_pd.zip:
#  - OAK_itineraries_pd.csv
# CSV files in OAK_itineraries_pe.zip:
#  - OAK_itineraries_pe.csv
# CSV files in OAK_itineraries_qa.zip:
#  - OAK_itineraries_qa.csv
# CSV files in OAK_itineraries_rz.zip:
#  - OAK_itineraries_rz.csv
# CSV files in OAK_itineraries_si.zip:
#  - OAK_itineraries_si.csv
# CSV files in OAK_itineraries_pr.zip:
#  - OAK_itineraries_pr.csv
# CSV files in OAK_itineraries_rm.zip:
#  - OAK_itineraries_rm.csv
# CSV files in OAK_itineraries_qv.zip:
#  - OAK_itineraries_qv.csv
# CSV files in OAK_itineraries_hc.zip:
#  - OAK_itineraries_hc.csv
# CSV files in OAK_itineraries_kx.zip:
#  - OAK_itineraries_kx.csv
# CSV files in OAK_itineraries_ig.zip:
#  - OAK_itineraries_ig.csv
# CSV files in OAK_itineraries_ko.zip:
#  - OAK_itineraries_ko.csv
# CSV files in OAK_itineraries_ht.zip:
#  - OAK_itineraries_ht.csv
# CSV files in OAK_itineraries_jk.zip:
#  - OAK_itineraries_jk.csv
# CSV files in OAK_itineraries_ip.zip:
#  - OAK_itineraries_ip.csv
# CSV files in OAK_itineraries_ed.zip:
#  - OAK_itineraries_ed.csv
# CSV files in OAK_itineraries_dw.zip:
#  - OAK_itineraries_dw.csv
# CSV files in OAK_itineraries_gl.zip:
#  - OAK_itineraries_gl.csv
# CSV files in OAK_itineraries_es.zip:
#  - OAK_itineraries_es.csv
# CSV files in OAK_itineraries_fh.zip:
#  - OAK_itineraries_fh.csv
# CSV files in OAK_itineraries_gn.zip:
#  - OAK_itineraries_gn.csv
# CSV files in OAK_itineraries_du.zip:
#  - OAK_itineraries_du.csv
# CSV files in OAK_itineraries_fj.zip:
#  - OAK_itineraries_fj.csv
# CSV files in OAK_itineraries_eq.zip:
#  - OAK_itineraries_eq.csv
# CSV files in OAK_itineraries_db.zip:
#  - OAK_itineraries_db.csv
# CSV files in OAK_itineraries_gy.zip:
#  - OAK_itineraries_gy.csv
# CSV files in OAK_itineraries_ef.zip:
#  - OAK_itineraries_ef.csv
# CSV files in OAK_itineraries_hv.zip:
#  - OAK_itineraries_hv.csv
# CSV files in OAK_itineraries_km.zip:
#  - OAK_itineraries_km.csv
# CSV files in OAK_itineraries_ir.zip:
#  - OAK_itineraries_ir.csv
# CSV files in OAK_itineraries_ji.zip:
#  - OAK_itineraries_ji.csv
# CSV files in OAK_itineraries_kz.zip:
#  - OAK_itineraries_kz.csv
# CSV files in OAK_itineraries_ha.zip:
#  - OAK_itineraries_ha.csv
# CSV files in OAK_itineraries_ie.zip:
#  - OAK_itineraries_ie.csv
# CSV files in OAK_itineraries_pp.zip:
#  - OAK_itineraries_pp.csv
# CSV files in OAK_itineraries_sk.zip:
#  - OAK_itineraries_sk.csv
# CSV files in OAK_itineraries_qt.zip:
#  - OAK_itineraries_qt.csv
# CSV files in OAK_itineraries_ro.zip:
#  - OAK_itineraries_ro.csv
# CSV files in OAK_itineraries_pg.zip:
#  - OAK_itineraries_pg.csv
# CSV files in OAK_itineraries_rx.zip:
#  - OAK_itineraries_rx.csv
# CSV files in OAK_itineraries_qc.zip:
#  - OAK_itineraries_qc.csv
# CSV files in OAK_itineraries_qb.zip:
#  - OAK_itineraries_qb.csv
# CSV files in OAK_itineraries_ry.zip:
#  - OAK_itineraries_ry.csv
# CSV files in OAK_itineraries_pf.zip:
#  - OAK_itineraries_pf.csv
# CSV files in OAK_itineraries_rn.zip:
#  - OAK_itineraries_rn.csv
# CSV files in OAK_itineraries_qu.zip:
#  - OAK_itineraries_qu.csv
# CSV files in OAK_itineraries_sj.zip:
#  - OAK_itineraries_sj.csv
# CSV files in OAK_itineraries_pq.zip:
#  - OAK_itineraries_pq.csv
# CSV files in OAK_itineraries_id.zip:
#  - OAK_itineraries_id.csv
# CSV files in OAK_itineraries_jh.zip:
#  - OAK_itineraries_jh.csv
# CSV files in OAK_itineraries_is.zip:
#  - OAK_itineraries_is.csv
# CSV files in OAK_itineraries_kl.zip:
#  - OAK_itineraries_kl.csv
# CSV files in OAK_itineraries_hw.zip:
#  - OAK_itineraries_hw.csv
# CSV files in OAK_itineraries_eg.zip:
#  - OAK_itineraries_eg.csv
# CSV files in OAK_itineraries_gx.zip:
#  - OAK_itineraries_gx.csv
# CSV files in OAK_itineraries_dc.zip:
#  - OAK_itineraries_dc.csv
# CSV files in OAK_itineraries_ep.zip:
#  - OAK_itineraries_ep.csv
# CSV files in OAK_itineraries_fk.zip:
#  - OAK_itineraries_fk.csv
# CSV files in OAK_itineraries_dt.zip:
#  - OAK_itineraries_dt.csv
# CSV files in OAK_itineraries_go.zip:
#  - OAK_itineraries_go.csv
# CSV files in OAK_itineraries_dg.zip:
#  - OAK_itineraries_dg.csv
# CSV files in OAK_itineraries_ec.zip:
#  - OAK_itineraries_ec.csv
# CSV files in OAK_itineraries_fx.zip:
#  - OAK_itineraries_fx.csv
# CSV files in OAK_itineraries_gk.zip:
#  - OAK_itineraries_gk.csv
# CSV files in OAK_itineraries_dp.zip:
#  - OAK_itineraries_dp.csv
# CSV files in OAK_itineraries_fo.zip:
#  - OAK_itineraries_fo.csv
# CSV files in OAK_itineraries_et.zip:
#  - OAK_itineraries_et.csv
# CSV files in OAK_itineraries_hd.zip:
#  - OAK_itineraries_hd.csv
# CSV files in OAK_itineraries_hs.zip:
#  - OAK_itineraries_hs.csv
# CSV files in OAK_itineraries_kh.zip:
#  - OAK_itineraries_kh.csv
# CSV files in OAK_itineraries_iw.zip:
#  - OAK_itineraries_iw.csv
# CSV files in OAK_itineraries_jl.zip:
#  - OAK_itineraries_jl.csv
# CSV files in OAK_itineraries_sy.zip:
#  - OAK_itineraries_sy.csv
# CSV files in OAK_itineraries_pb.zip:
#  - OAK_itineraries_pb.csv
# CSV files in OAK_itineraries_qf.zip:
#  - OAK_itineraries_qf.csv
# CSV files in OAK_itineraries_pu.zip:
#  - OAK_itineraries_pu.csv
# CSV files in OAK_itineraries_sn.zip:
#  - OAK_itineraries_sn.csv
# CSV files in OAK_itineraries_qq.zip:
#  - OAK_itineraries_qq.csv
# CSV files in OAK_itineraries_rj.zip:
#  - OAK_itineraries_rj.csv
# CSV files in OAK_itineraries_rk.zip:
#  - OAK_itineraries_rk.csv
# CSV files in OAK_itineraries_qp.zip:
#  - OAK_itineraries_qp.csv
# CSV files in OAK_itineraries_so.zip:
#  - OAK_itineraries_so.csv
# CSV files in OAK_itineraries_pt.zip:
#  - OAK_itineraries_pt.csv
# CSV files in OAK_itineraries_qg.zip:
#  - OAK_itineraries_qg.csv
# CSV files in OAK_itineraries_pc.zip:
#  - OAK_itineraries_pc.csv
# CSV files in OAK_itineraries_sx.zip:
#  - OAK_itineraries_sx.csv
# CSV files in OAK_itineraries_jm.zip:
#  - OAK_itineraries_jm.csv
# CSV files in OAK_itineraries_iv.zip:
#  - OAK_itineraries_iv.csv
# CSV files in OAK_itineraries_ki.zip:
#  - OAK_itineraries_ki.csv
# CSV files in OAK_itineraries_hr.zip:
#  - OAK_itineraries_hr.csv
# CSV files in OAK_itineraries_ia.zip:
#  - OAK_itineraries_ia.csv
# CSV files in OAK_itineraries_jz.zip:
#  - OAK_itineraries_jz.csv
# CSV files in OAK_itineraries_he.zip:
#  - OAK_itineraries_he.csv
# CSV files in OAK_itineraries_eu.zip:
#  - OAK_itineraries_eu.csv
# CSV files in OAK_itineraries_fn.zip:
#  - OAK_itineraries_fn.csv
# CSV files in OAK_itineraries_dq.zip:
#  - OAK_itineraries_dq.csv
# CSV files in OAK_itineraries_gj.zip:
#  - OAK_itineraries_gj.csv
# CSV files in OAK_itineraries_fy.zip:
#  - OAK_itineraries_fy.csv
# CSV files in OAK_itineraries_eb.zip:
#  - OAK_itineraries_eb.csv
# CSV files in OAK_itineraries_df.zip:
#  - OAK_itineraries_df.csv
# CSV files in OAK_itineraries_dd.zip:
#  - OAK_itineraries_dd.csv
# CSV files in OAK_itineraries_fl.zip:
#  - OAK_itineraries_fl.csv
# CSV files in OAK_itineraries_ew.zip:
#  - OAK_itineraries_ew.csv
# CSV files in OAK_itineraries_gh.zip:
#  - OAK_itineraries_gh.csv
# CSV files in OAK_itineraries_ds.zip:
#  - OAK_itineraries_ds.csv
# CSV files in OAK_itineraries_jx.zip:
#  - OAK_itineraries_jx.csv
# CSV files in OAK_itineraries_ic.zip:
#  - OAK_itineraries_ic.csv
# CSV files in OAK_itineraries_hg.zip:
#  - OAK_itineraries_hg.csv
# CSV files in OAK_itineraries_it.zip:
#  - OAK_itineraries_it.csv
# CSV files in OAK_itineraries_jo.zip:
#  - OAK_itineraries_jo.csv
# CSV files in OAK_itineraries_hp.zip:
#  - OAK_itineraries_hp.csv
# CSV files in OAK_itineraries_kk.zip:
#  - OAK_itineraries_kk.csv
# CSV files in OAK_itineraries_qe.zip:
#  - OAK_itineraries_qe.csv
# CSV files in OAK_itineraries_sz.zip:
#  - OAK_itineraries_sz.csv
# CSV files in OAK_itineraries_pa.zip:
#  - OAK_itineraries_pa.csv
# CSV files in OAK_itineraries_qr.zip:
#  - OAK_itineraries_qr.csv
# CSV files in OAK_itineraries_ri.zip:
#  - OAK_itineraries_ri.csv
# CSV files in OAK_itineraries_pv.zip:
#  - OAK_itineraries_pv.csv
# CSV files in OAK_itineraries_sm.zip:
#  - OAK_itineraries_sm.csv
# CSV files in OAK_itineraries_sl.zip:
#  - OAK_itineraries_sl.csv
# CSV files in OAK_itineraries_pw.zip:
#  - OAK_itineraries_pw.csv
# CSV files in OAK_itineraries_rh.zip:
#  - OAK_itineraries_rh.csv
# CSV files in OAK_itineraries_qs.zip:
#  - OAK_itineraries_qs.csv
# CSV files in OAK_itineraries_qd.zip:
#  - OAK_itineraries_qd.csv
# CSV files in OAK_itineraries_kj.zip:
#  - OAK_itineraries_kj.csv
# CSV files in OAK_itineraries_hq.zip:
#  - OAK_itineraries_hq.csv
# CSV files in OAK_itineraries_jn.zip:
#  - OAK_itineraries_jn.csv
# CSV files in OAK_itineraries_iu.zip:
#  - OAK_itineraries_iu.csv
# CSV files in OAK_itineraries_hf.zip:
#  - OAK_itineraries_hf.csv
# CSV files in OAK_itineraries_ib.zip:
#  - OAK_itineraries_ib.csv
# CSV files in OAK_itineraries_jy.zip:
#  - OAK_itineraries_jy.csv
# CSV files in OAK_itineraries_dr.zip:
#  - OAK_itineraries_dr.csv
# CSV files in OAK_itineraries_gi.zip:
#  - OAK_itineraries_gi.csv
# CSV files in OAK_itineraries_ev.zip:
#  - OAK_itineraries_ev.csv
# CSV files in OAK_itineraries_fm.zip:
#  - OAK_itineraries_fm.csv
# CSV files in OAK_itineraries_de.zip:
#  - OAK_itineraries_de.csv
# CSV files in OAK_itineraries_fz.zip:
#  - OAK_itineraries_fz.csv
# CSV files in OAK_itineraries_ea.zip:
#  - OAK_itineraries_ea.csv
# CSV files in OAK_itineraries_dh.zip:
#  - OAK_itineraries_dh.csv
# CSV files in OAK_itineraries_gs.zip:
#  - OAK_itineraries_gs.csv
# CSV files in OAK_itineraries_el.zip:
#  - OAK_itineraries_el.csv
# CSV files in OAK_itineraries_fw.zip:
#  - OAK_itineraries_fw.csv
# CSV files in OAK_itineraries_gd.zip:
#  - OAK_itineraries_gd.csv
# CSV files in OAK_itineraries_kp.zip:
#  - OAK_itineraries_kp.csv
# CSV files in OAK_itineraries_hk.zip:
#  - OAK_itineraries_hk.csv
# CSV files in OAK_itineraries_jt.zip:
#  - OAK_itineraries_jt.csv
# CSV files in OAK_itineraries_io.zip:
#  - OAK_itineraries_io.csv
# CSV files in OAK_itineraries_kg.zip:
#  - OAK_itineraries_kg.csv
# CSV files in OAK_itineraries_ix.zip:
#  - OAK_itineraries_ix.csv
# CSV files in OAK_itineraries_jc.zip:
#  - OAK_itineraries_jc.csv
# CSV files in OAK_itineraries_sv.zip:
#  - OAK_itineraries_sv.csv
# CSV files in OAK_itineraries_pm.zip:
#  - OAK_itineraries_pm.csv
# CSV files in OAK_itineraries_rr.zip:
#  - OAK_itineraries_rr.csv
# CSV files in OAK_itineraries_qi.zip:
#  - OAK_itineraries_qi.csv
# CSV files in OAK_itineraries_pz.zip:
#  - OAK_itineraries_pz.csv
# CSV files in OAK_itineraries_sa.zip:
#  - OAK_itineraries_sa.csv
# CSV files in OAK_itineraries_re.zip:
#  - OAK_itineraries_re.csv
# CSV files in OAK_itineraries_rd.zip:
#  - OAK_itineraries_rd.csv
# CSV files in OAK_itineraries_qh.zip:
#  - OAK_itineraries_qh.csv
# CSV files in OAK_itineraries_rs.zip:
#  - OAK_itineraries_rs.csv
# CSV files in OAK_itineraries_pl.zip:
#  - OAK_itineraries_pl.csv
# CSV files in OAK_itineraries_sw.zip:
#  - OAK_itineraries_sw.csv
# CSV files in OAK_itineraries_jb.zip:
#  - OAK_itineraries_jb.csv
# CSV files in OAK_itineraries_iy.zip:
#  - OAK_itineraries_iy.csv
# CSV files in OAK_itineraries_kf.zip:
#  - OAK_itineraries_kf.csv
# CSV files in OAK_itineraries_in.zip:
#  - OAK_itineraries_in.csv
# CSV files in OAK_itineraries_ju.zip:
#  - OAK_itineraries_ju.csv
# CSV files in OAK_itineraries_hj.zip:
#  - OAK_itineraries_hj.csv
# CSV files in OAK_itineraries_kq.zip:
#  - OAK_itineraries_kq.csv
# CSV files in OAK_itineraries_ez.zip:
#  - OAK_itineraries_ez.csv
# CSV files in OAK_itineraries_fa.zip:
#  - OAK_itineraries_fa.csv
# CSV files in OAK_itineraries_ge.zip:
#  - OAK_itineraries_ge.csv
# CSV files in OAK_itineraries_fv.zip:
#  - OAK_itineraries_fv.csv
# CSV files in OAK_itineraries_em.zip:
#  - OAK_itineraries_em.csv
# CSV files in OAK_itineraries_gr.zip:
#  - OAK_itineraries_gr.csv
# CSV files in OAK_itineraries_di.zip:
#  - OAK_itineraries_di.csv
# CSV files in OAK_itineraries_eo.zip:
#  - OAK_itineraries_eo.csv
# CSV files in OAK_itineraries_ft.zip:
#  - OAK_itineraries_ft.csv
# CSV files in OAK_itineraries_dk.zip:
#  - OAK_itineraries_dk.csv
# CSV files in OAK_itineraries_gp.zip:
#  - OAK_itineraries_gp.csv
# CSV files in OAK_itineraries_fc.zip:
#  - OAK_itineraries_fc.csv
# CSV files in OAK_itineraries_ex.zip:
#  - OAK_itineraries_ex.csv
# CSV files in OAK_itineraries_gg.zip:
#  - OAK_itineraries_gg.csv
# CSV files in OAK_itineraries_jw.zip:
#  - OAK_itineraries_jw.csv
# CSV files in OAK_itineraries_il.zip:
#  - OAK_itineraries_il.csv
# CSV files in OAK_itineraries_ks.zip:
#  - OAK_itineraries_ks.csv
# CSV files in OAK_itineraries_hh.zip:
#  - OAK_itineraries_hh.csv
# CSV files in OAK_itineraries_kd.zip:
#  - OAK_itineraries_kd.csv
# CSV files in OAK_itineraries_rq.zip:
#  - OAK_itineraries_rq.csv
# CSV files in OAK_itineraries_qj.zip:
#  - OAK_itineraries_qj.csv
# CSV files in OAK_itineraries_su.zip:
#  - OAK_itineraries_su.csv
# CSV files in OAK_itineraries_pn.zip:
#  - OAK_itineraries_pn.csv
# CSV files in OAK_itineraries_rf.zip:
#  - OAK_itineraries_rf.csv
# CSV files in OAK_itineraries_py.zip:
#  - OAK_itineraries_py.csv
# CSV files in OAK_itineraries_sb.zip:
#  - OAK_itineraries_sb.csv
# CSV files in OAK_itineraries_sc.zip:
#  - OAK_itineraries_sc.csv
# CSV files in OAK_itineraries_px.zip:
#  - OAK_itineraries_px.csv
# CSV files in OAK_itineraries_rg.zip:
#  - OAK_itineraries_rg.csv
# CSV files in OAK_itineraries_po.zip:
#  - OAK_itineraries_po.csv
# CSV files in OAK_itineraries_st.zip:
#  - OAK_itineraries_st.csv
# CSV files in OAK_itineraries_qk.zip:
#  - OAK_itineraries_qk.csv
# CSV files in OAK_itineraries_rp.zip:
#  - OAK_itineraries_rp.csv
# CSV files in OAK_itineraries_ke.zip:
#  - OAK_itineraries_ke.csv
# CSV files in OAK_itineraries_ja.zip:
#  - OAK_itineraries_ja.csv
# CSV files in OAK_itineraries_iz.zip:
#  - OAK_itineraries_iz.csv
# CSV files in OAK_itineraries_hi.zip:
#  - OAK_itineraries_hi.csv
# CSV files in OAK_itineraries_kr.zip:
#  - OAK_itineraries_kr.csv
# CSV files in OAK_itineraries_im.zip:
#  - OAK_itineraries_im.csv
# CSV files in OAK_itineraries_jv.zip:
#  - OAK_itineraries_jv.csv
# CSV files in OAK_itineraries_gf.zip:
#  - OAK_itineraries_gf.csv
# CSV files in OAK_itineraries_ey.zip:
#  - OAK_itineraries_ey.csv
# CSV files in OAK_itineraries_fb.zip:
#  - OAK_itineraries_fb.csv
# CSV files in OAK_itineraries_gq.zip:
#  - OAK_itineraries_gq.csv
# CSV files in OAK_itineraries_dj.zip:
#  - OAK_itineraries_dj.csv
# CSV files in OAK_itineraries_fu.zip:
#  - OAK_itineraries_fu.csv
# CSV files in OAK_itineraries_en.zip:
#  - OAK_itineraries_en.csv
# CSV files in OAK_itineraries_ff.zip:
#  - OAK_itineraries_ff.csv
# CSV files in OAK_itineraries_gb.zip:
#  - OAK_itineraries_gb.csv
# CSV files in OAK_itineraries_dy.zip:
#  - OAK_itineraries_dy.csv
# CSV files in OAK_itineraries_ej.zip:
#  - OAK_itineraries_ej.csv
# CSV files in OAK_itineraries_fq.zip:
#  - OAK_itineraries_fq.csv
# CSV files in OAK_itineraries_dn.zip:
#  - OAK_itineraries_dn.csv
# CSV files in OAK_itineraries_gu.zip:
#  - OAK_itineraries_gu.csv
# CSV files in OAK_itineraries_je.zip:
#  - OAK_itineraries_je.csv
# CSV files in OAK_itineraries_hz.zip:
#  - OAK_itineraries_hz.csv
# CSV files in OAK_itineraries_ka.zip:
#  - OAK_itineraries_ka.csv
# CSV files in OAK_itineraries_jr.zip:
#  - OAK_itineraries_jr.csv
# CSV files in OAK_itineraries_ii.zip:
#  - OAK_itineraries_ii.csv
# CSV files in OAK_itineraries_kv.zip:
#  - OAK_itineraries_kv.csv
# CSV files in OAK_itineraries_hm.zip:
#  - OAK_itineraries_hm.csv
# CSV files in OAK_itineraries_qx.zip:
#  - OAK_itineraries_qx.csv
# CSV files in OAK_itineraries_rc.zip:
#  - OAK_itineraries_rc.csv
# CSV files in OAK_itineraries_sg.zip:
#  - OAK_itineraries_sg.csv
# CSV files in OAK_itineraries_rt.zip:
#  - OAK_itineraries_rt.csv
# CSV files in OAK_itineraries_qo.zip:
#  - OAK_itineraries_qo.csv
# CSV files in OAK_itineraries_sp.zip:
#  - OAK_itineraries_sp.csv
# CSV files in OAK_itineraries_pk.zip:
#  - OAK_itineraries_pk.csv
# CSV files in OAK_itineraries_pj.zip:
#  - OAK_itineraries_pj.csv
# CSV files in OAK_itineraries_sq.zip:
#  - OAK_itineraries_sq.csv
# CSV files in OAK_itineraries_qn.zip:
#  - OAK_itineraries_qn.csv
# CSV files in OAK_itineraries_ru.zip:
#  - OAK_itineraries_ru.csv
# CSV files in OAK_itineraries_sf.zip:
#  - OAK_itineraries_sf.csv
# CSV files in OAK_itineraries_rb.zip:
#  - OAK_itineraries_rb.csv
# CSV files in OAK_itineraries_qy.zip:
#  - OAK_itineraries_qy.csv
# CSV files in OAK_itineraries_hl.zip:
#  - OAK_itineraries_hl.csv
# CSV files in OAK_itineraries_kw.zip:
#  - OAK_itineraries_kw.csv
# CSV files in OAK_itineraries_ih.zip:
#  - OAK_itineraries_ih.csv
# CSV files in OAK_itineraries_js.zip:
#  - OAK_itineraries_js.csv
# CSV files in OAK_itineraries_jd.zip:
#  - OAK_itineraries_jd.csv
# CSV files in OAK_itineraries_gt.zip:
#  - OAK_itineraries_gt.csv
# CSV files in OAK_itineraries_do.zip:
#  - OAK_itineraries_do.csv
# CSV files in OAK_itineraries_fp.zip:
#  - OAK_itineraries_fp.csv
# CSV files in OAK_itineraries_ek.zip:
#  - OAK_itineraries_ek.csv
# CSV files in OAK_itineraries_dx.zip:
#  - OAK_itineraries_dx.csv
# CSV files in OAK_itineraries_gc.zip:
#  - OAK_itineraries_gc.csv
# CSV files in OAK_itineraries_fg.zip:
#  - OAK_itineraries_fg.csv
# CSV files in OAK_itineraries_ga.zip:
#  - OAK_itineraries_ga.csv
# CSV files in OAK_itineraries_dz.zip:
#  - OAK_itineraries_dz.csv
# CSV files in OAK_itineraries_fe.zip:
#  - OAK_itineraries_fe.csv
# CSV files in OAK_itineraries_dm.zip:
#  - OAK_itineraries_dm.csv
# CSV files in OAK_itineraries_gv.zip:
#  - OAK_itineraries_gv.csv
# CSV files in OAK_itineraries_ei.zip:
#  - OAK_itineraries_ei.csv
# CSV files in OAK_itineraries_fr.zip:
#  - OAK_itineraries_fr.csv
# CSV files in OAK_itineraries_hy.zip:
#  - OAK_itineraries_hy.csv
# CSV files in OAK_itineraries_kb.zip:
#  - OAK_itineraries_kb.csv
# CSV files in OAK_itineraries_jf.zip:
#  - OAK_itineraries_jf.csv
# CSV files in OAK_itineraries_ku.zip:
#  - OAK_itineraries_ku.csv
# CSV files in OAK_itineraries_hn.zip:
#  - OAK_itineraries_hn.csv
# CSV files in OAK_itineraries_jq.zip:
#  - OAK_itineraries_jq.csv
# CSV files in OAK_itineraries_ij.zip:
#  - OAK_itineraries_ij.csv
# CSV files in OAK_itineraries_sd.zip:
#  - OAK_itineraries_sd.csv
# CSV files in OAK_itineraries_ss.zip:
#  - OAK_itineraries_ss.csv
# CSV files in OAK_itineraries_ph.zip:
#  - OAK_itineraries_ph.csv
# CSV files in OAK_itineraries_rw.zip:
#  - OAK_itineraries_rw.csv
# CSV files in OAK_itineraries_ql.zip:
#  - OAK_itineraries_ql.csv
# CSV files in OAK_itineraries_qm.zip:
#  - OAK_itineraries_qm.csv
# CSV files in OAK_itineraries_rv.zip:
#  - OAK_itineraries_rv.csv
# CSV files in OAK_itineraries_pi.zip:
#  - OAK_itineraries_pi.csv
# CSV files in OAK_itineraries_sr.zip:
#  - OAK_itineraries_sr.csv
# CSV files in OAK_itineraries_ra.zip:
#  - OAK_itineraries_ra.csv
# CSV files in OAK_itineraries_qz.zip:
#  - OAK_itineraries_qz.csv
# CSV files in OAK_itineraries_se.zip:
#  - OAK_itineraries_se.csv
# CSV files in OAK_itineraries_ik.zip:
#  - OAK_itineraries_ik.csv
# CSV files in OAK_itineraries_jp.zip:
#  - OAK_itineraries_jp.csv
# CSV files in OAK_itineraries_ho.zip:
#  - OAK_itineraries_ho.csv
# CSV files in OAK_itineraries_kt.zip:
#  - OAK_itineraries_kt.csv
# CSV files in OAK_itineraries_jg.zip:
#  - OAK_itineraries_jg.csv
# CSV files in OAK_itineraries_kc.zip:
#  - OAK_itineraries_kc.csv
# CSV files in OAK_itineraries_hx.zip:
#  - OAK_itineraries_hx.csv
# CSV files in OAK_itineraries_fs.zip:
#  - OAK_itineraries_fs.csv
# CSV files in OAK_itineraries_eh.zip:
#  - OAK_itineraries_eh.csv
# CSV files in OAK_itineraries_gw.zip:
#  - OAK_itineraries_gw.csv
# CSV files in OAK_itineraries_dl.zip:
#  - OAK_itineraries_dl.csv
# CSV files in OAK_itineraries_fd.zip:
#  - OAK_itineraries_fd.csv
# CSV files in OAK_itineraries_bk.zip:
#  - OAK_itineraries_bk.csv
# CSV files in OAK_itineraries_ap.zip:
#  - OAK_itineraries_ap.csv
# CSV files in OAK_itineraries_co.zip:
#  - OAK_itineraries_co.csv
# CSV files in OAK_itineraries_ag.zip:
#  - OAK_itineraries_ag.csv
# CSV files in OAK_itineraries_cx.zip:
#  - OAK_itineraries_cx.csv
# CSV files in OAK_itineraries_ms.zip:
#  - OAK_itineraries_ms.csv
# CSV files in OAK_itineraries_nh.zip:
#  - OAK_itineraries_nh.csv
# CSV files in OAK_itineraries_lw.zip:
#  - OAK_itineraries_lw.csv
# CSV files in OAK_itineraries_ol.zip:
#  - OAK_itineraries_ol.csv
# CSV files in OAK_itineraries_md.zip:
#  - OAK_itineraries_md.csv
# CSV files in OAK_itineraries_zm.zip:
#  - OAK_itineraries_zm.csv
# CSV files in OAK_itineraries_yv.zip:
#  - OAK_itineraries_yv.csv
# CSV files in OAK_itineraries_xr.zip:
#  - OAK_itineraries_xr.csv
# CSV files in OAK_itineraries_ya.zip:
#  - OAK_itineraries_ya.csv
# CSV files in OAK_itineraries_zz.zip:
#  - OAK_itineraries_zz.csv
# CSV files in OAK_itineraries_xe.zip:
#  - OAK_itineraries_xe.csv
# CSV files in OAK_itineraries_uu.zip:
#  - OAK_itineraries_uu.csv
# CSV files in OAK_itineraries_vn.zip:
#  - OAK_itineraries_vn.csv
# CSV files in OAK_itineraries_tq.zip:
#  - OAK_itineraries_tq.csv
# CSV files in OAK_itineraries_wj.zip:
#  - OAK_itineraries_wj.csv
# CSV files in OAK_itineraries_vy.zip:
#  - OAK_itineraries_vy.csv
# CSV files in OAK_itineraries_ub.zip:
#  - OAK_itineraries_ub.csv
# CSV files in OAK_itineraries_tf.zip:
#  - OAK_itineraries_tf.csv
# CSV files in OAK_itineraries_tg.zip:
#  - OAK_itineraries_tg.csv
# CSV files in OAK_itineraries_uc.zip:
#  - OAK_itineraries_uc.csv
# CSV files in OAK_itineraries_vx.zip:
#  - OAK_itineraries_vx.csv
# CSV files in OAK_itineraries_wk.zip:
#  - OAK_itineraries_wk.csv
# CSV files in OAK_itineraries_tp.zip:
#  - OAK_itineraries_tp.csv
# CSV files in OAK_itineraries_vo.zip:
#  - OAK_itineraries_vo.csv
# CSV files in OAK_itineraries_ut.zip:
#  - OAK_itineraries_ut.csv
# CSV files in OAK_itineraries_xd.zip:
#  - OAK_itineraries_xd.csv
# CSV files in OAK_itineraries_xs.zip:
#  - OAK_itineraries_xs.csv
# CSV files in OAK_itineraries_yw.zip:
#  - OAK_itineraries_yw.csv
# CSV files in OAK_itineraries_zl.zip:
#  - OAK_itineraries_zl.csv
# CSV files in OAK_itineraries_la.zip:
#  - OAK_itineraries_la.csv
# CSV files in OAK_itineraries_oz.zip:
#  - OAK_itineraries_oz.csv
# CSV files in OAK_itineraries_me.zip:
#  - OAK_itineraries_me.csv
# CSV files in OAK_itineraries_om.zip:
#  - OAK_itineraries_om.csv
# CSV files in OAK_itineraries_lv.zip:
#  - OAK_itineraries_lv.csv
# CSV files in OAK_itineraries_ni.zip:
#  - OAK_itineraries_ni.csv
# CSV files in OAK_itineraries_mr.zip:
#  - OAK_itineraries_mr.csv
# CSV files in OAK_itineraries_cy.zip:
#  - OAK_itineraries_cy.csv
# CSV files in OAK_itineraries_af.zip:
#  - OAK_itineraries_af.csv
# CSV files in OAK_itineraries_cn.zip:
#  - OAK_itineraries_cn.csv
# CSV files in OAK_itineraries_aq.zip:
#  - OAK_itineraries_aq.csv
# CSV files in OAK_itineraries_bj.zip:
#  - OAK_itineraries_bj.csv
# CSV files in OAK_itineraries_cl.zip:
#  - OAK_itineraries_cl.csv
# CSV files in OAK_itineraries_bh.zip:
#  - OAK_itineraries_bh.csv
# CSV files in OAK_itineraries_as.zip:
#  - OAK_itineraries_as.csv
# CSV files in OAK_itineraries_ad.zip:
#  - OAK_itineraries_ad.csv
# CSV files in OAK_itineraries_lt.zip:
#  - OAK_itineraries_lt.csv
# CSV files in OAK_itineraries_oo.zip:
#  - OAK_itineraries_oo.csv
# CSV files in OAK_itineraries_mp.zip:
#  - OAK_itineraries_mp.csv
# CSV files in OAK_itineraries_nk.zip:
#  - OAK_itineraries_nk.csv
# CSV files in OAK_itineraries_ox.zip:
#  - OAK_itineraries_ox.csv
# CSV files in OAK_itineraries_lc.zip:
#  - OAK_itineraries_lc.csv
# CSV files in OAK_itineraries_mg.zip:
#  - OAK_itineraries_mg.csv
# CSV files in OAK_itineraries_xq.zip:
#  - OAK_itineraries_xq.csv
# CSV files in OAK_itineraries_zn.zip:
#  - OAK_itineraries_zn.csv
# CSV files in OAK_itineraries_yu.zip:
#  - OAK_itineraries_yu.csv
# CSV files in OAK_itineraries_xf.zip:
#  - OAK_itineraries_xf.csv
# CSV files in OAK_itineraries_yb.zip:
#  - OAK_itineraries_yb.csv
# CSV files in OAK_itineraries_zy.zip:
#  - OAK_itineraries_zy.csv
# CSV files in OAK_itineraries_tr.zip:
#  - OAK_itineraries_tr.csv
# CSV files in OAK_itineraries_wi.zip:
#  - OAK_itineraries_wi.csv
# CSV files in OAK_itineraries_uv.zip:
#  - OAK_itineraries_uv.csv
# CSV files in OAK_itineraries_vm.zip:
#  - OAK_itineraries_vm.csv
# CSV files in OAK_itineraries_te.zip:
#  - OAK_itineraries_te.csv
# CSV files in OAK_itineraries_vz.zip:
#  - OAK_itineraries_vz.csv
# CSV files in OAK_itineraries_ua.zip:
#  - OAK_itineraries_ua.csv
# CSV files in OAK_itineraries_td.zip:
#  - OAK_itineraries_td.csv
# CSV files in OAK_itineraries_vl.zip:
#  - OAK_itineraries_vl.csv
# CSV files in OAK_itineraries_uw.zip:
#  - OAK_itineraries_uw.csv
# CSV files in OAK_itineraries_wh.zip:
#  - OAK_itineraries_wh.csv
# CSV files in OAK_itineraries_ts.zip:
#  - OAK_itineraries_ts.csv
# CSV files in OAK_itineraries_zx.zip:
#  - OAK_itineraries_zx.csv
# CSV files in OAK_itineraries_yc.zip:
#  - OAK_itineraries_yc.csv
# CSV files in OAK_itineraries_xg.zip:
#  - OAK_itineraries_xg.csv
# CSV files in OAK_itineraries_yt.zip:
#  - OAK_itineraries_yt.csv
# CSV files in OAK_itineraries_zo.zip:
#  - OAK_itineraries_zo.csv
# CSV files in OAK_itineraries_xp.zip:
#  - OAK_itineraries_xp.csv
# CSV files in OAK_itineraries_mf.zip:
#  - OAK_itineraries_mf.csv
# CSV files in OAK_itineraries_lb.zip:
#  - OAK_itineraries_lb.csv
# CSV files in OAK_itineraries_oy.zip:
#  - OAK_itineraries_oy.csv
# CSV files in OAK_itineraries_nj.zip:
#  - OAK_itineraries_nj.csv
# CSV files in OAK_itineraries_mq.zip:
#  - OAK_itineraries_mq.csv
# CSV files in OAK_itineraries_on.zip:
#  - OAK_itineraries_on.csv
# CSV files in OAK_itineraries_lu.zip:
#  - OAK_itineraries_lu.csv
# CSV files in OAK_itineraries_ae.zip:
#  - OAK_itineraries_ae.csv
# CSV files in OAK_itineraries_cz.zip:
#  - OAK_itineraries_cz.csv
# CSV files in OAK_itineraries_ar.zip:
#  - OAK_itineraries_ar.csv
# CSV files in OAK_itineraries_bi.zip:
#  - OAK_itineraries_bi.csv
# CSV files in OAK_itineraries_cm.zip:
#  - OAK_itineraries_cm.csv
# CSV files in OAK_itineraries_aa.zip:
#  - OAK_itineraries_aa.csv
# CSV files in OAK_itineraries_bz.zip:
#  - OAK_itineraries_bz.csv
# CSV files in OAK_itineraries_ci.zip:
#  - OAK_itineraries_ci.csv
# CSV files in OAK_itineraries_bm.zip:
#  - OAK_itineraries_bm.csv
# CSV files in OAK_itineraries_av.zip:
#  - OAK_itineraries_av.csv
# CSV files in OAK_itineraries_lf.zip:
#  - OAK_itineraries_lf.csv
# CSV files in OAK_itineraries_ny.zip:
#  - OAK_itineraries_ny.csv
# CSV files in OAK_itineraries_mb.zip:
#  - OAK_itineraries_mb.csv
# CSV files in OAK_itineraries_lq.zip:
#  - OAK_itineraries_lq.csv
# CSV files in OAK_itineraries_oj.zip:
#  - OAK_itineraries_oj.csv
# CSV files in OAK_itineraries_mu.zip:
#  - OAK_itineraries_mu.csv
# CSV files in OAK_itineraries_nn.zip:
#  - OAK_itineraries_nn.csv
# CSV files in OAK_itineraries_xc.zip:
#  - OAK_itineraries_xc.csv
# CSV files in OAK_itineraries_yg.zip:
#  - OAK_itineraries_yg.csv
# CSV files in OAK_itineraries_xt.zip:
#  - OAK_itineraries_xt.csv
# CSV files in OAK_itineraries_zk.zip:
#  - OAK_itineraries_zk.csv
# CSV files in OAK_itineraries_yp.zip:
#  - OAK_itineraries_yp.csv
# CSV files in OAK_itineraries_ud.zip:
#  - OAK_itineraries_ud.csv
# CSV files in OAK_itineraries_tw.zip:
#  - OAK_itineraries_tw.csv
# CSV files in OAK_itineraries_wl.zip:
#  - OAK_itineraries_wl.csv
# CSV files in OAK_itineraries_us.zip:
#  - OAK_itineraries_us.csv
# CSV files in OAK_itineraries_vh.zip:
#  - OAK_itineraries_vh.csv
# CSV files in OAK_itineraries_vi.zip:
#  - OAK_itineraries_vi.csv
# CSV files in OAK_itineraries_ur.zip:
#  - OAK_itineraries_ur.csv
# CSV files in OAK_itineraries_wm.zip:
#  - OAK_itineraries_wm.csv
# CSV files in OAK_itineraries_tv.zip:
#  - OAK_itineraries_tv.csv
# CSV files in OAK_itineraries_ue.zip:
#  - OAK_itineraries_ue.csv
# CSV files in OAK_itineraries_ta.zip:
#  - OAK_itineraries_ta.csv
# CSV files in OAK_itineraries_wz.zip:
#  - OAK_itineraries_wz.csv
# CSV files in OAK_itineraries_yq.zip:
#  - OAK_itineraries_yq.csv
# CSV files in OAK_itineraries_zj.zip:
#  - OAK_itineraries_zj.csv
# CSV files in OAK_itineraries_xu.zip:
#  - OAK_itineraries_xu.csv
# CSV files in OAK_itineraries_yf.zip:
#  - OAK_itineraries_yf.csv
# CSV files in OAK_itineraries_xb.zip:
#  - OAK_itineraries_xb.csv
# CSV files in OAK_itineraries_no.zip:
#  - OAK_itineraries_no.csv
# CSV files in OAK_itineraries_mt.zip:
#  - OAK_itineraries_mt.csv
# CSV files in OAK_itineraries_ok.zip:
#  - OAK_itineraries_ok.csv
# CSV files in OAK_itineraries_lp.zip:
#  - OAK_itineraries_lp.csv
# CSV files in OAK_itineraries_mc.zip:
#  - OAK_itineraries_mc.csv
# CSV files in OAK_itineraries_nx.zip:
#  - OAK_itineraries_nx.csv
# CSV files in OAK_itineraries_lg.zip:
#  - OAK_itineraries_lg.csv
# CSV files in OAK_itineraries_aw.zip:
#  - OAK_itineraries_aw.csv
# CSV files in OAK_itineraries_bl.zip:
#  - OAK_itineraries_bl.csv
# CSV files in OAK_itineraries_ch.zip:
#  - OAK_itineraries_ch.csv
# CSV files in OAK_itineraries_ab.zip:
#  - OAK_itineraries_ab.csv
# CSV files in OAK_itineraries_by.zip:
#  - OAK_itineraries_by.csv
# CSV files in OAK_itineraries_bn.zip:
#  - OAK_itineraries_bn.csv
# CSV files in OAK_itineraries_au.zip:
#  - OAK_itineraries_au.csv
# CSV files in OAK_itineraries_cj.zip:
#  - OAK_itineraries_cj.csv
# CSV files in OAK_itineraries_nz.zip:
#  - OAK_itineraries_nz.csv
# CSV files in OAK_itineraries_ma.zip:
#  - OAK_itineraries_ma.csv
# CSV files in OAK_itineraries_le.zip:
#  - OAK_itineraries_le.csv
# CSV files in OAK_itineraries_mv.zip:
#  - OAK_itineraries_mv.csv
# CSV files in OAK_itineraries_nm.zip:
#  - OAK_itineraries_nm.csv
# CSV files in OAK_itineraries_lr.zip:
#  - OAK_itineraries_lr.csv
# CSV files in OAK_itineraries_oi.zip:
#  - OAK_itineraries_oi.csv
# CSV files in OAK_itineraries_yd.zip:
#  - OAK_itineraries_yd.csv
# CSV files in OAK_itineraries_zh.zip:
#  - OAK_itineraries_zh.csv
# CSV files in OAK_itineraries_ys.zip:
#  - OAK_itineraries_ys.csv
# CSV files in OAK_itineraries_xw.zip:
#  - OAK_itineraries_xw.csv
# CSV files in OAK_itineraries_ug.zip:
#  - OAK_itineraries_ug.csv
# CSV files in OAK_itineraries_wx.zip:
#  - OAK_itineraries_wx.csv
# CSV files in OAK_itineraries_tc.zip:
#  - OAK_itineraries_tc.csv
# CSV files in OAK_itineraries_up.zip:
#  - OAK_itineraries_up.csv
# CSV files in OAK_itineraries_vk.zip:
#  - OAK_itineraries_vk.csv
# CSV files in OAK_itineraries_tt.zip:
#  - OAK_itineraries_tt.csv
# CSV files in OAK_itineraries_wo.zip:
#  - OAK_itineraries_wo.csv
# CSV files in OAK_itineraries_wn.zip:
#  - OAK_itineraries_wn.csv
# CSV files in OAK_itineraries_tu.zip:
#  - OAK_itineraries_tu.csv
# CSV files in OAK_itineraries_vj.zip:
#  - OAK_itineraries_vj.csv
# CSV files in OAK_itineraries_uq.zip:
#  - OAK_itineraries_uq.csv
# CSV files in OAK_itineraries_tb.zip:
#  - OAK_itineraries_tb.csv
# CSV files in OAK_itineraries_wy.zip:
#  - OAK_itineraries_wy.csv
# CSV files in OAK_itineraries_uf.zip:
#  - OAK_itineraries_uf.csv
# CSV files in OAK_itineraries_xv.zip:
#  - OAK_itineraries_xv.csv
# CSV files in OAK_itineraries_yr.zip:
#  - OAK_itineraries_yr.csv
# CSV files in OAK_itineraries_zi.zip:
#  - OAK_itineraries_zi.csv
# CSV files in OAK_itineraries_xa.zip:
#  - OAK_itineraries_xa.csv
# CSV files in OAK_itineraries_ye.zip:
#  - OAK_itineraries_ye.csv
# CSV files in OAK_itineraries_oh.zip:
#  - OAK_itineraries_oh.csv
# CSV files in OAK_itineraries_ls.zip:
#  - OAK_itineraries_ls.csv
# CSV files in OAK_itineraries_nl.zip:
#  - OAK_itineraries_nl.csv
# CSV files in OAK_itineraries_mw.zip:
#  - OAK_itineraries_mw.csv
# CSV files in OAK_itineraries_ld.zip:
#  - OAK_itineraries_ld.csv
# CSV files in OAK_itineraries_ck.zip:
#  - OAK_itineraries_ck.csv
# CSV files in OAK_itineraries_at.zip:
#  - OAK_itineraries_at.csv
# CSV files in OAK_itineraries_bo.zip:
#  - OAK_itineraries_bo.csv
# CSV files in OAK_itineraries_bx.zip:
#  - OAK_itineraries_bx.csv
# CSV files in OAK_itineraries_ac.zip:
#  - OAK_itineraries_ac.csv
# CSV files in DEN_itineraries_zb.zip:
#  - DEN_itineraries_zb.csv
# CSV files in DEN_itineraries_yy.zip:
#  - DEN_itineraries_yy.csv
# CSV files in DEN_itineraries_xj.zip:
#  - DEN_itineraries_xj.csv
# CSV files in DEN_itineraries_yn.zip:
#  - DEN_itineraries_yn.csv
# CSV files in DEN_itineraries_zu.zip:
#  - DEN_itineraries_zu.csv
# CSV files in DEN_itineraries_we.zip:
#  - DEN_itineraries_we.csv
# CSV files in DEN_itineraries_uz.zip:
#  - DEN_itineraries_uz.csv
# CSV files in DEN_itineraries_va.zip:
#  - DEN_itineraries_va.csv
# CSV files in DEN_itineraries_wr.zip:
#  - DEN_itineraries_wr.csv
# CSV files in DEN_itineraries_ti.zip:
#  - DEN_itineraries_ti.csv
# CSV files in DEN_itineraries_vv.zip:
#  - DEN_itineraries_vv.csv
# CSV files in DEN_itineraries_um.zip:
#  - DEN_itineraries_um.csv
# CSV files in DEN_itineraries_bd.zip:
#  - DEN_itineraries_bd.csv
# CSV files in DEN_itineraries_cw.zip:
#  - DEN_itineraries_cw.csv
# CSV files in DEN_itineraries_ah.zip:
#  - DEN_itineraries_ah.csv
# CSV files in DEN_itineraries_bs.zip:
#  - DEN_itineraries_bs.csv
# CSV files in DEN_itineraries_lx.zip:
#  - DEN_itineraries_lx.csv
# CSV files in DEN_itineraries_oc.zip:
#  - DEN_itineraries_oc.csv
# CSV files in DEN_itineraries_ng.zip:
#  - DEN_itineraries_ng.csv
# CSV files in DEN_itineraries_ot.zip:
#  - DEN_itineraries_ot.csv
# CSV files in DEN_itineraries_lo.zip:
#  - DEN_itineraries_lo.csv
# CSV files in DEN_itineraries_np.zip:
#  - DEN_itineraries_np.csv
# CSV files in DEN_itineraries_mk.zip:
#  - DEN_itineraries_mk.csv
# CSV files in DEN_itineraries_mj.zip:
#  - DEN_itineraries_mj.csv
# CSV files in DEN_itineraries_nq.zip:
#  - DEN_itineraries_nq.csv
# CSV files in DEN_itineraries_ln.zip:
#  - DEN_itineraries_ln.csv
# CSV files in DEN_itineraries_ou.zip:
#  - DEN_itineraries_ou.csv
# CSV files in DEN_itineraries_nf.zip:
#  - DEN_itineraries_nf.csv
# CSV files in DEN_itineraries_ob.zip:
#  - DEN_itineraries_ob.csv
# CSV files in DEN_itineraries_ly.zip:
#  - DEN_itineraries_ly.csv
# CSV files in DEN_itineraries_br.zip:
#  - DEN_itineraries_br.csv
# CSV files in DEN_itineraries_ai.zip:
#  - DEN_itineraries_ai.csv
# CSV files in DEN_itineraries_cv.zip:
#  - DEN_itineraries_cv.csv
# CSV files in DEN_itineraries_be.zip:
#  - DEN_itineraries_be.csv
# CSV files in DEN_itineraries_ca.zip:
#  - DEN_itineraries_ca.csv
# CSV files in DEN_itineraries_ul.zip:
#  - DEN_itineraries_ul.csv
# CSV files in DEN_itineraries_vw.zip:
#  - DEN_itineraries_vw.csv
# CSV files in DEN_itineraries_th.zip:
#  - DEN_itineraries_th.csv
# CSV files in DEN_itineraries_ws.zip:
#  - DEN_itineraries_ws.csv
# CSV files in DEN_itineraries_wd.zip:
#  - DEN_itineraries_wd.csv
# CSV files in DEN_itineraries_zt.zip:
#  - DEN_itineraries_zt.csv
# CSV files in DEN_itineraries_yo.zip:
#  - DEN_itineraries_yo.csv
# CSV files in DEN_itineraries_xk.zip:
#  - DEN_itineraries_xk.csv
# CSV files in DEN_itineraries_yx.zip:
#  - DEN_itineraries_yx.csv
# CSV files in DEN_itineraries_zc.zip:
#  - DEN_itineraries_zc.csv
# CSV files in DEN_itineraries_za.zip:
#  - DEN_itineraries_za.csv
# CSV files in DEN_itineraries_yz.zip:
#  - DEN_itineraries_yz.csv
# CSV files in DEN_itineraries_ym.zip:
#  - DEN_itineraries_ym.csv
# CSV files in DEN_itineraries_zv.zip:
#  - DEN_itineraries_zv.csv
# CSV files in DEN_itineraries_xi.zip:
#  - DEN_itineraries_xi.csv
# CSV files in DEN_itineraries_uy.zip:
#  - DEN_itineraries_uy.csv
# CSV files in DEN_itineraries_vb.zip:
#  - DEN_itineraries_vb.csv
# CSV files in DEN_itineraries_wf.zip:
#  - DEN_itineraries_wf.csv
# CSV files in DEN_itineraries_vu.zip:
#  - DEN_itineraries_vu.csv
# CSV files in DEN_itineraries_un.zip:
#  - DEN_itineraries_un.csv
# CSV files in DEN_itineraries_wq.zip:
#  - DEN_itineraries_wq.csv
# CSV files in DEN_itineraries_tj.zip:
#  - DEN_itineraries_tj.csv
# CSV files in DEN_itineraries_bg.zip:
#  - DEN_itineraries_bg.csv
# CSV files in DEN_itineraries_cc.zip:
#  - DEN_itineraries_cc.csv
# CSV files in DEN_itineraries_ak.zip:
#  - DEN_itineraries_ak.csv
# CSV files in DEN_itineraries_bp.zip:
#  - DEN_itineraries_bp.csv
# CSV files in DEN_itineraries_ct.zip:
#  - DEN_itineraries_ct.csv
# CSV files in DEN_itineraries_nd.zip:
#  - DEN_itineraries_nd.csv
# CSV files in DEN_itineraries_ns.zip:
#  - DEN_itineraries_ns.csv
# CSV files in DEN_itineraries_mh.zip:
#  - DEN_itineraries_mh.csv
# CSV files in DEN_itineraries_ow.zip:
#  - DEN_itineraries_ow.csv
# CSV files in DEN_itineraries_ll.zip:
#  - DEN_itineraries_ll.csv
# CSV files in DEN_itineraries_lm.zip:
#  - DEN_itineraries_lm.csv
# CSV files in DEN_itineraries_ov.zip:
#  - DEN_itineraries_ov.csv
# CSV files in DEN_itineraries_mi.zip:
#  - DEN_itineraries_mi.csv
# CSV files in DEN_itineraries_nr.zip:
#  - DEN_itineraries_nr.csv
# CSV files in DEN_itineraries_oa.zip:
#  - DEN_itineraries_oa.csv
# CSV files in DEN_itineraries_lz.zip:
#  - DEN_itineraries_lz.csv
# CSV files in DEN_itineraries_ne.zip:
#  - DEN_itineraries_ne.csv
# CSV files in DEN_itineraries_cu.zip:
#  - DEN_itineraries_cu.csv
# CSV files in DEN_itineraries_bq.zip:
#  - DEN_itineraries_bq.csv
# CSV files in DEN_itineraries_aj.zip:
#  - DEN_itineraries_aj.csv
# CSV files in DEN_itineraries_cb.zip:
#  - DEN_itineraries_cb.csv
# CSV files in DEN_itineraries_bf.zip:
#  - DEN_itineraries_bf.csv
# CSV files in DEN_itineraries_tk.zip:
#  - DEN_itineraries_tk.csv
# CSV files in DEN_itineraries_wp.zip:
#  - DEN_itineraries_wp.csv
# CSV files in DEN_itineraries_uo.zip:
#  - DEN_itineraries_uo.csv
# CSV files in DEN_itineraries_vt.zip:
#  - DEN_itineraries_vt.csv
# CSV files in DEN_itineraries_wg.zip:
#  - DEN_itineraries_wg.csv
# CSV files in DEN_itineraries_vc.zip:
#  - DEN_itineraries_vc.csv
# CSV files in DEN_itineraries_ux.zip:
# ...
#  - MIA_itineraries_bn.csv
# CSV files in MIA_itineraries_au.zip:
#  - MIA_itineraries_au.csv
# CSV files in MIA_itineraries_cj.zip:
#  - MIA_itineraries_cj.csv
# CSV files in MIA_itineraries_ab.zip:
#  - MIA_itineraries_ab.csv
# CSV files in MIA_itineraries_by.zip:
#  - MIA_itineraries_by.csv
# CSV files in MIA_itineraries_cn.zip:
#  - MIA_itineraries_cn.csv
# CSV files in MIA_itineraries_aq.zip:
#  - MIA_itineraries_aq.csv
# CSV files in MIA_itineraries_bj.zip:
#  - MIA_itineraries_bj.csv
# CSV files in MIA_itineraries_cy.zip:
#  - MIA_itineraries_cy.csv
# CSV files in MIA_itineraries_af.zip:
#  - MIA_itineraries_af.csv
# CSV files in MIA_itineraries_om.zip:
#  - MIA_itineraries_om.csv
# CSV files in MIA_itineraries_lv.zip:
#  - MIA_itineraries_lv.csv
# CSV files in MIA_itineraries_ni.zip:
#  - MIA_itineraries_ni.csv
# CSV files in MIA_itineraries_mr.zip:
#  - MIA_itineraries_mr.csv
# CSV files in MIA_itineraries_la.zip:
#  - MIA_itineraries_la.csv
# CSV files in MIA_itineraries_oz.zip:
#  - MIA_itineraries_oz.csv
# CSV files in MIA_itineraries_me.zip:
#  - MIA_itineraries_me.csv
# CSV files in MIA_itineraries_xs.zip:
#  - MIA_itineraries_xs.csv
# CSV files in MIA_itineraries_yw.zip:
#  - MIA_itineraries_yw.csv
# CSV files in MIA_itineraries_zl.zip:
#  - MIA_itineraries_zl.csv
# CSV files in MIA_itineraries_xd.zip:
#  - MIA_itineraries_xd.csv
# CSV files in MIA_itineraries_wk.zip:
#  - MIA_itineraries_wk.csv
# CSV files in MIA_itineraries_tp.zip:
#  - MIA_itineraries_tp.csv
# CSV files in MIA_itineraries_vo.zip:
#  - MIA_itineraries_vo.csv
# CSV files in MIA_itineraries_ut.zip:
#  - MIA_itineraries_ut.csv
# CSV files in MIA_itineraries_tg.zip:
#  - MIA_itineraries_tg.csv
# CSV files in MIA_itineraries_uc.zip:
#  - MIA_itineraries_uc.csv
# CSV files in MIA_itineraries_vx.zip:
#  - MIA_itineraries_vx.csv
# CSV files in MIA_itineraries_vy.zip:
#  - MIA_itineraries_vy.csv
# CSV files in MIA_itineraries_ub.zip:
#  - MIA_itineraries_ub.csv
# CSV files in MIA_itineraries_tf.zip:
#  - MIA_itineraries_tf.csv
# CSV files in MIA_itineraries_uu.zip:
#  - MIA_itineraries_uu.csv
# CSV files in MIA_itineraries_vn.zip:
#  - MIA_itineraries_vn.csv
# CSV files in MIA_itineraries_tq.zip:
#  - MIA_itineraries_tq.csv
# CSV files in MIA_itineraries_wj.zip:
#  - MIA_itineraries_wj.csv
# CSV files in MIA_itineraries_ya.zip:
#  - MIA_itineraries_ya.csv
# CSV files in MIA_itineraries_zz.zip:
#  - MIA_itineraries_zz.csv
# CSV files in MIA_itineraries_xe.zip:
#  - MIA_itineraries_xe.csv
# CSV files in MIA_itineraries_zm.zip:
#  - MIA_itineraries_zm.csv
# CSV files in MIA_itineraries_yv.zip:
#  - MIA_itineraries_yv.csv
# CSV files in MIA_itineraries_xr.zip:
#  - MIA_itineraries_xr.csv
# CSV files in MIA_itineraries_md.zip:
#  - MIA_itineraries_md.csv
# CSV files in MIA_itineraries_ms.zip:
#  - MIA_itineraries_ms.csv
# CSV files in MIA_itineraries_nh.zip:
#  - MIA_itineraries_nh.csv
# CSV files in MIA_itineraries_lw.zip:
#  - MIA_itineraries_lw.csv
# CSV files in MIA_itineraries_ol.zip:
#  - MIA_itineraries_ol.csv
# CSV files in MIA_itineraries_ag.zip:
#  - MIA_itineraries_ag.csv
# CSV files in MIA_itineraries_cx.zip:
#  - MIA_itineraries_cx.csv
# CSV files in MIA_itineraries_bk.zip:
#  - MIA_itineraries_bk.csv
# CSV files in MIA_itineraries_ap.zip:
#  - MIA_itineraries_ap.csv
# CSV files in MIA_itineraries_co.zip:
#  - MIA_itineraries_co.csv
# CSV files in MIA_itineraries_ar.zip:
#  - MIA_itineraries_ar.csv
# CSV files in MIA_itineraries_bi.zip:
#  - MIA_itineraries_bi.csv
# CSV files in MIA_itineraries_cm.zip:
#  - MIA_itineraries_cm.csv
# CSV files in MIA_itineraries_ae.zip:
#  - MIA_itineraries_ae.csv
# CSV files in MIA_itineraries_cz.zip:
#  - MIA_itineraries_cz.csv
# CSV files in MIA_itineraries_nj.zip:
#  - MIA_itineraries_nj.csv
# CSV files in MIA_itineraries_mq.zip:
#  - MIA_itineraries_mq.csv
# CSV files in MIA_itineraries_on.zip:
#  - MIA_itineraries_on.csv
# CSV files in MIA_itineraries_lu.zip:
#  - MIA_itineraries_lu.csv
# CSV files in MIA_itineraries_mf.zip:
#  - MIA_itineraries_mf.csv
# CSV files in MIA_itineraries_lb.zip:
#  - MIA_itineraries_lb.csv
# CSV files in MIA_itineraries_oy.zip:
#  - MIA_itineraries_oy.csv
# CSV files in MIA_itineraries_yt.zip:
#  - MIA_itineraries_yt.csv
# CSV files in MIA_itineraries_zo.zip:
#  - MIA_itineraries_zo.csv
# CSV files in MIA_itineraries_xp.zip:
#  - MIA_itineraries_xp.csv
# CSV files in MIA_itineraries_zx.zip:
#  - MIA_itineraries_zx.csv
# CSV files in MIA_itineraries_yc.zip:
#  - MIA_itineraries_yc.csv
# CSV files in MIA_itineraries_xg.zip:
#  - MIA_itineraries_xg.csv
# CSV files in MIA_itineraries_vl.zip:
#  - MIA_itineraries_vl.csv
# CSV files in MIA_itineraries_uw.zip:
#  - MIA_itineraries_uw.csv
# CSV files in MIA_itineraries_wh.zip:
#  - MIA_itineraries_wh.csv
# CSV files in MIA_itineraries_ts.zip:
#  - MIA_itineraries_ts.csv
# CSV files in MIA_itineraries_td.zip:
#  - MIA_itineraries_td.csv
# CSV files in MIA_itineraries_te.zip:
#  - MIA_itineraries_te.csv
# CSV files in MIA_itineraries_vz.zip:
#  - MIA_itineraries_vz.csv
# CSV files in MIA_itineraries_ua.zip:
#  - MIA_itineraries_ua.csv
# CSV files in MIA_itineraries_tr.zip:
#  - MIA_itineraries_tr.csv
# CSV files in MIA_itineraries_wi.zip:
#  - MIA_itineraries_wi.csv
# CSV files in MIA_itineraries_uv.zip:
#  - MIA_itineraries_uv.csv
# CSV files in MIA_itineraries_vm.zip:
#  - MIA_itineraries_vm.csv
# CSV files in MIA_itineraries_xf.zip:
#  - MIA_itineraries_xf.csv
# CSV files in MIA_itineraries_yb.zip:
#  - MIA_itineraries_yb.csv
# CSV files in MIA_itineraries_zy.zip:
#  - MIA_itineraries_zy.csv
# CSV files in MIA_itineraries_xq.zip:
#  - MIA_itineraries_xq.csv
# CSV files in MIA_itineraries_zn.zip:
#  - MIA_itineraries_zn.csv
# CSV files in MIA_itineraries_yu.zip:
#  - MIA_itineraries_yu.csv
# CSV files in MIA_itineraries_ox.zip:
#  - MIA_itineraries_ox.csv
# CSV files in MIA_itineraries_lc.zip:
#  - MIA_itineraries_lc.csv
# CSV files in MIA_itineraries_mg.zip:
#  - MIA_itineraries_mg.csv
# CSV files in MIA_itineraries_lt.zip:
#  - MIA_itineraries_lt.csv
# CSV files in MIA_itineraries_oo.zip:
#  - MIA_itineraries_oo.csv
# CSV files in MIA_itineraries_mp.zip:
#  - MIA_itineraries_mp.csv
# CSV files in MIA_itineraries_nk.zip:
#  - MIA_itineraries_nk.csv
# CSV files in MIA_itineraries_ad.zip:
#  - MIA_itineraries_ad.csv
# CSV files in MIA_itineraries_cl.zip:
#  - MIA_itineraries_cl.csv
# CSV files in MIA_itineraries_bh.zip:
#  - MIA_itineraries_bh.csv
# CSV files in MIA_itineraries_as.zip:
#  - MIA_itineraries_as.csv
# CSV files in MIA_itineraries_dx.zip:
#  - MIA_itineraries_dx.csv
# CSV files in MIA_itineraries_gc.zip:
#  - MIA_itineraries_gc.csv
# CSV files in MIA_itineraries_fg.zip:
#  - MIA_itineraries_fg.csv
# CSV files in MIA_itineraries_gt.zip:
#  - MIA_itineraries_gt.csv
# CSV files in MIA_itineraries_do.zip:
#  - MIA_itineraries_do.csv
# CSV files in MIA_itineraries_fp.zip:
#  - MIA_itineraries_fp.csv
# CSV files in MIA_itineraries_ek.zip:
#  - MIA_itineraries_ek.csv
# CSV files in MIA_itineraries_jd.zip:
#  - MIA_itineraries_jd.csv
# CSV files in MIA_itineraries_hl.zip:
#  - MIA_itineraries_hl.csv
# CSV files in MIA_itineraries_kw.zip:
#  - MIA_itineraries_kw.csv
# CSV files in MIA_itineraries_ih.zip:
#  - MIA_itineraries_ih.csv
# CSV files in MIA_itineraries_js.zip:
#  - MIA_itineraries_js.csv
# CSV files in MIA_itineraries_sf.zip:
#  - MIA_itineraries_sf.csv
# CSV files in MIA_itineraries_rb.zip:
#  - MIA_itineraries_rb.csv
# CSV files in MIA_itineraries_qy.zip:
#  - MIA_itineraries_qy.csv
# CSV files in MIA_itineraries_pj.zip:
#  - MIA_itineraries_pj.csv
# CSV files in MIA_itineraries_sq.zip:
#  - MIA_itineraries_sq.csv
# CSV files in MIA_itineraries_qn.zip:
#  - MIA_itineraries_qn.csv
# CSV files in MIA_itineraries_ru.zip:
#  - MIA_itineraries_ru.csv
# CSV files in MIA_itineraries_rt.zip:
#  - MIA_itineraries_rt.csv
# CSV files in MIA_itineraries_qo.zip:
#  - MIA_itineraries_qo.csv
# CSV files in MIA_itineraries_sp.zip:
#  - MIA_itineraries_sp.csv
# CSV files in MIA_itineraries_pk.zip:
#  - MIA_itineraries_pk.csv
# CSV files in MIA_itineraries_qx.zip:
#  - MIA_itineraries_qx.csv
# CSV files in MIA_itineraries_rc.zip:
#  - MIA_itineraries_rc.csv
# CSV files in MIA_itineraries_sg.zip:
#  - MIA_itineraries_sg.csv
# CSV files in MIA_itineraries_jr.zip:
#  - MIA_itineraries_jr.csv
# CSV files in MIA_itineraries_ii.zip:
#  - MIA_itineraries_ii.csv
# CSV files in MIA_itineraries_kv.zip:
#  - MIA_itineraries_kv.csv
# CSV files in MIA_itineraries_hm.zip:
#  - MIA_itineraries_hm.csv
# CSV files in MIA_itineraries_je.zip:
#  - MIA_itineraries_je.csv
# CSV files in MIA_itineraries_hz.zip:
#  - MIA_itineraries_hz.csv
# CSV files in MIA_itineraries_ka.zip:
#  - MIA_itineraries_ka.csv
# CSV files in MIA_itineraries_ej.zip:
#  - MIA_itineraries_ej.csv
# CSV files in MIA_itineraries_fq.zip:
#  - MIA_itineraries_fq.csv
# CSV files in MIA_itineraries_dn.zip:
#  - MIA_itineraries_dn.csv
# CSV files in MIA_itineraries_gu.zip:
#  - MIA_itineraries_gu.csv
# CSV files in MIA_itineraries_ff.zip:
#  - MIA_itineraries_ff.csv
# CSV files in MIA_itineraries_gb.zip:
#  - MIA_itineraries_gb.csv
# CSV files in MIA_itineraries_dy.zip:
#  - MIA_itineraries_dy.csv
# CSV files in MIA_itineraries_fd.zip:
#  - MIA_itineraries_fd.csv
# CSV files in MIA_itineraries_fs.zip:
#  - MIA_itineraries_fs.csv
# CSV files in MIA_itineraries_eh.zip:
#  - MIA_itineraries_eh.csv
# CSV files in MIA_itineraries_gw.zip:
#  - MIA_itineraries_gw.csv
# CSV files in MIA_itineraries_dl.zip:
#  - MIA_itineraries_dl.csv
# CSV files in MIA_itineraries_jg.zip:
#  - MIA_itineraries_jg.csv
# CSV files in MIA_itineraries_kc.zip:
#  - MIA_itineraries_kc.csv
# CSV files in MIA_itineraries_hx.zip:
#  - MIA_itineraries_hx.csv
# CSV files in MIA_itineraries_ik.zip:
#  - MIA_itineraries_ik.csv
# CSV files in MIA_itineraries_jp.zip:
#  - MIA_itineraries_jp.csv
# CSV files in MIA_itineraries_ho.zip:
#  - MIA_itineraries_ho.csv
# CSV files in MIA_itineraries_kt.zip:
#  - MIA_itineraries_kt.csv
# CSV files in MIA_itineraries_ra.zip:
#  - MIA_itineraries_ra.csv
# CSV files in MIA_itineraries_qz.zip:
#  - MIA_itineraries_qz.csv
# CSV files in MIA_itineraries_se.zip:
#  - MIA_itineraries_se.csv
# CSV files in MIA_itineraries_qm.zip:
#  - MIA_itineraries_qm.csv
# CSV files in MIA_itineraries_rv.zip:
#  - MIA_itineraries_rv.csv
# CSV files in MIA_itineraries_pi.zip:
#  - MIA_itineraries_pi.csv
# CSV files in MIA_itineraries_sr.zip:
#  - MIA_itineraries_sr.csv
# CSV files in MIA_itineraries_ss.zip:
#  - MIA_itineraries_ss.csv
# CSV files in MIA_itineraries_ph.zip:
#  - MIA_itineraries_ph.csv
# CSV files in MIA_itineraries_rw.zip:
#  - MIA_itineraries_rw.csv
# CSV files in MIA_itineraries_ql.zip:
#  - MIA_itineraries_ql.csv
# CSV files in MIA_itineraries_sd.zip:
#  - MIA_itineraries_sd.csv
# CSV files in MIA_itineraries_ku.zip:
#  - MIA_itineraries_ku.csv
# CSV files in MIA_itineraries_hn.zip:
#  - MIA_itineraries_hn.csv
# CSV files in MIA_itineraries_jq.zip:
#  - MIA_itineraries_jq.csv
# CSV files in MIA_itineraries_ij.zip:
#  - MIA_itineraries_ij.csv
# CSV files in MIA_itineraries_hy.zip:
#  - MIA_itineraries_hy.csv
# CSV files in MIA_itineraries_kb.zip:
#  - MIA_itineraries_kb.csv
# CSV files in MIA_itineraries_jf.zip:
#  - MIA_itineraries_jf.csv
# CSV files in MIA_itineraries_dm.zip:
#  - MIA_itineraries_dm.csv
# CSV files in MIA_itineraries_gv.zip:
#  - MIA_itineraries_gv.csv
# CSV files in MIA_itineraries_ei.zip:
#  - MIA_itineraries_ei.csv
# CSV files in MIA_itineraries_fr.zip:
#  - MIA_itineraries_fr.csv
# CSV files in MIA_itineraries_ga.zip:
#  - MIA_itineraries_ga.csv
# CSV files in MIA_itineraries_dz.zip:
#  - MIA_itineraries_dz.csv
# CSV files in MIA_itineraries_fe.zip:
#  - MIA_itineraries_fe.csv
# CSV files in MIA_itineraries_fv.zip:
#  - MIA_itineraries_fv.csv
# CSV files in MIA_itineraries_em.zip:
#  - MIA_itineraries_em.csv
# CSV files in MIA_itineraries_gr.zip:
#  - MIA_itineraries_gr.csv
# CSV files in MIA_itineraries_di.zip:
#  - MIA_itineraries_di.csv
# CSV files in MIA_itineraries_ez.zip:
#  - MIA_itineraries_ez.csv
# CSV files in MIA_itineraries_fa.zip:
#  - MIA_itineraries_fa.csv
# CSV files in MIA_itineraries_ge.zip:
#  - MIA_itineraries_ge.csv
# CSV files in MIA_itineraries_in.zip:
#  - MIA_itineraries_in.csv
# CSV files in MIA_itineraries_ju.zip:
#  - MIA_itineraries_ju.csv
# CSV files in MIA_itineraries_hj.zip:
#  - MIA_itineraries_hj.csv
# CSV files in MIA_itineraries_kq.zip:
#  - MIA_itineraries_kq.csv
# CSV files in MIA_itineraries_jb.zip:
#  - MIA_itineraries_jb.csv
# CSV files in MIA_itineraries_iy.zip:
#  - MIA_itineraries_iy.csv
# CSV files in MIA_itineraries_kf.zip:
#  - MIA_itineraries_kf.csv
# CSV files in MIA_itineraries_qh.zip:
#  - MIA_itineraries_qh.csv
# CSV files in MIA_itineraries_rs.zip:
#  - MIA_itineraries_rs.csv
# CSV files in MIA_itineraries_pl.zip:
#  - MIA_itineraries_pl.csv
# CSV files in MIA_itineraries_sw.zip:
#  - MIA_itineraries_sw.csv
# CSV files in MIA_itineraries_rd.zip:
#  - MIA_itineraries_rd.csv
# CSV files in MIA_itineraries_pz.zip:
#  - MIA_itineraries_pz.csv
# CSV files in MIA_itineraries_sa.zip:
#  - MIA_itineraries_sa.csv
# CSV files in MIA_itineraries_re.zip:
#  - MIA_itineraries_re.csv
# CSV files in MIA_itineraries_sv.zip:
#  - MIA_itineraries_sv.csv
# CSV files in MIA_itineraries_pm.zip:
#  - MIA_itineraries_pm.csv
# CSV files in MIA_itineraries_rr.zip:
#  - MIA_itineraries_rr.csv
# CSV files in MIA_itineraries_qi.zip:
#  - MIA_itineraries_qi.csv
# CSV files in MIA_itineraries_kg.zip:
#  - MIA_itineraries_kg.csv
# CSV files in MIA_itineraries_ix.zip:
#  - MIA_itineraries_ix.csv
# CSV files in MIA_itineraries_jc.zip:
#  - MIA_itineraries_jc.csv
# CSV files in MIA_itineraries_kp.zip:
#  - MIA_itineraries_kp.csv
# CSV files in MIA_itineraries_hk.zip:
#  - MIA_itineraries_hk.csv
# CSV files in MIA_itineraries_jt.zip:
#  - MIA_itineraries_jt.csv
# CSV files in MIA_itineraries_io.zip:
#  - MIA_itineraries_io.csv
# CSV files in MIA_itineraries_gd.zip:
#  - MIA_itineraries_gd.csv
# CSV files in MIA_itineraries_dh.zip:
#  - MIA_itineraries_dh.csv
# CSV files in MIA_itineraries_gs.zip:
#  - MIA_itineraries_gs.csv
# CSV files in MIA_itineraries_el.zip:
#  - MIA_itineraries_el.csv
# CSV files in MIA_itineraries_fw.zip:
#  - MIA_itineraries_fw.csv
# CSV files in MIA_itineraries_gq.zip:
#  - MIA_itineraries_gq.csv
# CSV files in MIA_itineraries_dj.zip:
#  - MIA_itineraries_dj.csv
# CSV files in MIA_itineraries_fu.zip:
#  - MIA_itineraries_fu.csv
# CSV files in MIA_itineraries_en.zip:
#  - MIA_itineraries_en.csv
# CSV files in MIA_itineraries_gf.zip:
#  - MIA_itineraries_gf.csv
# CSV files in MIA_itineraries_ey.zip:
#  - MIA_itineraries_ey.csv
# CSV files in MIA_itineraries_fb.zip:
#  - MIA_itineraries_fb.csv
# CSV files in MIA_itineraries_hi.zip:
#  - MIA_itineraries_hi.csv
# CSV files in MIA_itineraries_kr.zip:
#  - MIA_itineraries_kr.csv
# CSV files in MIA_itineraries_im.zip:
#  - MIA_itineraries_im.csv
# CSV files in MIA_itineraries_jv.zip:
#  - MIA_itineraries_jv.csv
# CSV files in MIA_itineraries_ke.zip:
#  - MIA_itineraries_ke.csv
# CSV files in MIA_itineraries_ja.zip:
#  - MIA_itineraries_ja.csv
# CSV files in MIA_itineraries_iz.zip:
#  - MIA_itineraries_iz.csv
# CSV files in MIA_itineraries_po.zip:
#  - MIA_itineraries_po.csv
# CSV files in MIA_itineraries_st.zip:
#  - MIA_itineraries_st.csv
# CSV files in MIA_itineraries_qk.zip:
#  - MIA_itineraries_qk.csv
# CSV files in MIA_itineraries_rp.zip:
#  - MIA_itineraries_rp.csv
# CSV files in MIA_itineraries_sc.zip:
#  - MIA_itineraries_sc.csv
# CSV files in MIA_itineraries_px.zip:
#  - MIA_itineraries_px.csv
# CSV files in MIA_itineraries_rg.zip:
#  - MIA_itineraries_rg.csv
# CSV files in MIA_itineraries_rf.zip:
#  - MIA_itineraries_rf.csv
# CSV files in MIA_itineraries_py.zip:
#  - MIA_itineraries_py.csv
# CSV files in MIA_itineraries_sb.zip:
#  - MIA_itineraries_sb.csv
# CSV files in MIA_itineraries_rq.zip:
#  - MIA_itineraries_rq.csv
# CSV files in MIA_itineraries_qj.zip:
#  - MIA_itineraries_qj.csv
# CSV files in MIA_itineraries_su.zip:
#  - MIA_itineraries_su.csv
# CSV files in MIA_itineraries_pn.zip:
#  - MIA_itineraries_pn.csv
# CSV files in MIA_itineraries_kd.zip:
#  - MIA_itineraries_kd.csv
# CSV files in MIA_itineraries_jw.zip:
#  - MIA_itineraries_jw.csv
# CSV files in MIA_itineraries_il.zip:
#  - MIA_itineraries_il.csv
# CSV files in MIA_itineraries_ks.zip:
#  - MIA_itineraries_ks.csv
# CSV files in MIA_itineraries_hh.zip:
#  - MIA_itineraries_hh.csv
# CSV files in MIA_itineraries_fc.zip:
#  - MIA_itineraries_fc.csv
# CSV files in MIA_itineraries_ex.zip:
#  - MIA_itineraries_ex.csv
# CSV files in MIA_itineraries_gg.zip:
#  - MIA_itineraries_gg.csv
# CSV files in MIA_itineraries_eo.zip:
#  - MIA_itineraries_eo.csv
# CSV files in MIA_itineraries_ft.zip:
#  - MIA_itineraries_ft.csv
# CSV files in MIA_itineraries_dk.zip:
#  - MIA_itineraries_dk.csv
# CSV files in MIA_itineraries_gp.zip:
#  - MIA_itineraries_gp.csv

# %%
import os
import zipfile
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

def list_csv_files_in_zips(folder_path):
    """
    Lists all CSV files within multiple ZIP archives in a folder.

    Parameters:
    folder_path (str): The path to the folder containing ZIP files.

    Returns:
    dict: A dictionary with ZIP file names as keys and a list of CSV file names as values.
    """
    csv_files = {}
    
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.zip'):
                zip_path = os.path.join(root, file)
                try:
                    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                        csv_list = [name for name in zip_ref.namelist() if name.endswith('.csv')]
                        if csv_list:
                            csv_files[zip_path] = csv_list
                except Exception as e:
                    csv_files[zip_path] = f"An error occurred: {e}"
    
    return csv_files

def read_csv_from_zip(zip_path, csv_file):
    """
    Reads a CSV file from a ZIP archive and returns it as a DataFrame.

    Parameters:
    zip_path (str): The path to the ZIP file.
    csv_file (str): The name of the CSV file within the ZIP archive.

    Returns:
    pd.DataFrame: A DataFrame containing the data from the CSV file.
    """
    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            with zip_ref.open(csv_file) as f:
                return pd.read_csv(f)
    except Exception as e:
        print(f"An error occurred while reading {csv_file} from {zip_path}: {e}")
        return pd.DataFrame()

def merge_csv_files_from_zips_to_dataframe(folder_path):
    """
    Merges all CSV files within multiple ZIP archives in a folder into one DataFrame.

    Parameters:
    folder_path (str): The path to the folder containing ZIP files.

    Returns:
    pd.DataFrame: A DataFrame containing the merged data from all CSV files.
    """
    csv_files = list_csv_files_in_zips(folder_path)
    merged_df = pd.DataFrame()
    
    with ThreadPoolExecutor() as executor:
        futures = []
        for zip_path, csv_list in csv_files.items():
            if isinstance(csv_list, list):
                for csv_file in csv_list:
                    futures.append(executor.submit(read_csv_from_zip, zip_path, csv_file))
        
        for future in futures:
            df = future.result()
            merged_df = pd.concat([merged_df, df], ignore_index=True)
    
    return merged_df

# Example usage
folder_path = '/Users/thusondube/Downloads/itineraries_csv'
merged_df = merge_csv_files_from_zips_to_dataframe(folder_path)

# %%
folder_path = '/Users/thusondube/Downloads/itineraries_csv'
merged_df = merge_csv_files_from_zips_to_dataframe(folder_path)

# %%
import os
import zipfile
import pandas as pd

def list_csv_files_in_zips(folder_path, max_folders=2):
    """
    Lists all CSV files within the first two ZIP archives in a folder.

    Parameters:
    folder_path (str): The path to the folder containing ZIP files.
    max_folders (int): The maximum number of ZIP folders to process.

    Returns:
    dict: A dictionary with ZIP file names as keys and a list of CSV file names as values.
    """
    csv_files = {}
    folder_count = 0
    
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.zip'):
                zip_path = os.path.join(root, file)
                try:
                    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                        csv_list = [name for name in zip_ref.namelist() if name.endswith('.csv')]
                        if csv_list:
                            csv_files[zip_path] = csv_list
                            folder_count += 1
                            if folder_count >= max_folders:
                                return csv_files
                except Exception as e:
                    csv_files[zip_path] = f"An error occurred: {e}"
    
    return csv_files

def merge_csv_files_from_zips_to_dataframe(folder_path, max_folders=2):
    """
    Merges all CSV files within the first two ZIP archives in a folder into one DataFrame.

    Parameters:
    folder_path (str): The path to the folder containing ZIP files.
    max_folders (int): The maximum number of ZIP folders to process.

    Returns:
    pd.DataFrame: A DataFrame containing the merged data from all CSV files.
    """
    csv_files = list_csv_files_in_zips(folder_path, max_folders)
    merged_df = pd.DataFrame()
    
    for zip_path, csv_list in csv_files.items():
        if isinstance(csv_list, list):
            with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                for csv_file in csv_list:
                    with zip_ref.open(csv_file) as f:
                        df = pd.read_csv(f)
                        merged_df = pd.concat([merged_df, df], ignore_index=True)
    
    return merged_df

# Example usage
folder_path = '/Users/thusondube/Downloads/itineraries_csv'
merged_df = merge_csv_files_from_zips_to_dataframe(folder_path)
merged_df.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  e1b137527b9175d7d930c3af82e70ae0  2022-04-19  2022-05-20             OAK
# 1  d813ebd107e3fa700206c0d96015da7a  2022-04-19  2022-05-20             OAK
# 2  e8ece5ad6f5962c696e06e031fc2a24a  2022-04-19  2022-05-20             OAK
# 3  c004a54681335100f326c9613b3c9448  2022-04-19  2022-05-20             OAK
# 4  4a42bbf77211b4afa7b9e14005949120  2022-04-19  2022-05-20             OAK
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL        PT7H52M           False         False      False
# 1                ATL        PT6H15M           False         False      False
# 2                ATL         PT9H6M           False         False      False
# 3                ATL        PT6H17M           False         False      False
# 4                ATL       PT14H12M           False         False      False
#
#    totalFare  ...  segmentsArrivalTimeEpochSeconds  \
# 0     103.98  ...           1653107460||1653126600
# 1     216.58  ...           1653067080||1653084660
# 2     216.58  ...           1653056820||1653084660
# 3     237.58  ...           1653110940||1653127980
# 4     307.21  ...           1653115560||1653159180
#
#                               segmentsArrivalTimeRaw  \
# 0  2022-05-20T22:31:00.000-06:00||2022-05-21T05:5...
# 1  2022-05-20T10:18:00.000-07:00||2022-05-20T18:1...
# 2  2022-05-20T07:27:00.000-07:00||2022-05-20T18:1...
# 3  2022-05-20T22:29:00.000-07:00||2022-05-21T06:1...
# 4  2022-05-20T23:46:00.000-07:00||2022-05-21T14:5...
#
#   segmentsArrivalAirportCode segmentsDepartureAirportCode  \
# 0                   DEN||ATL                     OAK||DEN
# 1                   LAX||ATL                     OAK||LAX
# 2                   LAX||ATL                     OAK||LAX
# 3                   LAS||ATL                     OAK||LAS
# 4                   SEA||ATL                     OAK||SEA
#
#                     segmentsAirlineName segmentsAirlineCode  \
# 0  Frontier Airlines||Frontier Airlines              F9||F9
# 1      Spirit Airlines||Spirit Airlines              NK||NK
# 2      Spirit Airlines||Spirit Airlines              NK||NK
# 3      Spirit Airlines||Spirit Airlines              NK||NK
# 4      Alaska Airlines||Alaska Airlines              AS||AS
#
#                         segmentsEquipmentDescription  \
# 0                                      ||Airbus A320
# 1                  ||AIRBUS INDUSTRIE A320 SHARKLETS
# 2  AIRBUS INDUSTRIE A320 SHARKLETS||AIRBUS INDUST...
# 3       AIRBUS INDUSTRIE A320 SHARKLETS||Airbus A319
# 4                     Boeing 737-900||Boeing 737-900
#
#   segmentsDurationInSeconds segmentsDistance segmentsCabinCode
# 0               9180||10620        943||1207      coach||coach
# 1               4920||15600       None||None      coach||coach
# 2               4920||15600       None||None      coach||coach
# 3               5580||13980       None||None      coach||coach
# 4               7500||17580        672||2178      coach||coach
#
# [5 rows x 23 columns]

# %%
import os
import zipfile
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

def list_csv_files_in_zips(folder_path):
    """
    Lists all CSV files within multiple ZIP archives in a folder.

    Parameters:
    folder_path (str): The path to the folder containing ZIP files.

    Returns:
    dict: A dictionary with ZIP file names as keys and a list of CSV file names as values.
    """
    csv_files = {}
    
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.zip'):
                zip_path = os.path.join(root, file)
                try:
                    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                        csv_list = [name for name in zip_ref.namelist() if name.endswith('.csv')]
                        if csv_list:
                            csv_files[zip_path] = csv_list
                except Exception as e:
                    csv_files[zip_path] = f"An error occurred: {e}"
    
    return csv_files

def read_csv_from_zip(zip_path, csv_file):
    """
    Reads a CSV file from a ZIP archive and returns it as a DataFrame.

    Parameters:
    zip_path (str): The path to the ZIP file.
    csv_file (str): The name of the CSV file within the ZIP archive.

    Returns:
    pd.DataFrame: A DataFrame containing the data from the CSV file.
    """
    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            with zip_ref.open(csv_file) as f:
                return pd.read_csv(f)
    except Exception as e:
        print(f"An error occurred while reading {csv_file} from {zip_path}: {e}")
        return pd.DataFrame()

def merge_csv_files_from_zips_to_parquet(folder_path, output_file):
    """
    Merges all CSV files within multiple ZIP archives in a folder into one Parquet file.

    Parameters:
    folder_path (str): The path to the folder containing ZIP files.
    output_file (str): The path to the output Parquet file.
    """
    csv_files = list_csv_files_in_zips(folder_path)
    merged_df = pd.DataFrame()
    
    with ThreadPoolExecutor() as executor:
        futures = []
        for zip_path, csv_list in csv_files.items():
            if isinstance(csv_list, list):
                for csv_file in csv_list:
                    futures.append(executor.submit(read_csv_from_zip, zip_path, csv_file))
        
        for future in futures:
            df = future.result()
            merged_df = pd.concat([merged_df, df], ignore_index=True)
    
    merged_df.to_parquet(output_file, engine='pyarrow')
    print(f"All CSV files have been merged and saved to {output_file}")

# Example usage
folder_path = '/Users/thusondube/Downloads/itineraries_csv'
output_file = '/Users/thusondube/Downloads/merged_output.parquet'
merge_csv_files_from_zips_to_parquet(folder_path, output_file)

# %%
import pandas as pd
import numpy as np 
import os
import zipfile


# Set the path to the root directory containing the zip files
root_dir = '/Users/thusondube/Downloads/itineraries_csv'

# Initialize an empty list to hold DataFrames
df_list = []

# Walk through the root directory
for folder_name, subfolders, filenames in os.walk(root_dir):
    for filename in filenames:
        if filename.endswith('.zip'):
            # Get the full path to the zip file
            zip_file_path = os.path.join(folder_name, filename)
            
            # Open the zip file
            with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
                # Loop through files inside the zip and check if it's a CSV
                for file in zip_ref.namelist():
                    if file.endswith('.csv'):
                        # Read the CSV into a DataFrame
                        with zip_ref.open(file) as f:
                            df = pd.read_csv(f)
                            # Append the DataFrame to the list
                            df_list.append(df)

# Concatenate all DataFrames into one
merged_df = pd.concat(df_list, ignore_index=True)

# %%
merged_df.head(1000000)
# Out:
#                                    legId  searchDate  flightDate  \
# 0       e1b137527b9175d7d930c3af82e70ae0  2022-04-19  2022-05-20
# 1       d813ebd107e3fa700206c0d96015da7a  2022-04-19  2022-05-20
# 2       e8ece5ad6f5962c696e06e031fc2a24a  2022-04-19  2022-05-20
# 3       c004a54681335100f326c9613b3c9448  2022-04-19  2022-05-20
# 4       4a42bbf77211b4afa7b9e14005949120  2022-04-19  2022-05-20
# ...                                  ...         ...         ...
# 999995  3db73913d6456af29f8d3a14cf3a5a32  2022-05-05  2022-06-29
# 999996  cbbc46342387fe5aeae12d862be63b04  2022-05-05  2022-06-29
# 999997  6f45a7dd496ff123e979cba6afc984e3  2022-05-05  2022-06-29
# 999998  77aa8436fd69662e8131d5a48b6e962c  2022-05-05  2022-06-29
# 999999  9babee5d8f1d92afbd9fdb9384401f11  2022-05-05  2022-06-29
#
#        startingAirport destinationAirport travelDuration  isBasicEconomy  \
# 0                  OAK                ATL        PT7H52M           False
# 1                  OAK                ATL        PT6H15M           False
# 2                  OAK                ATL         PT9H6M           False
# 3                  OAK                ATL        PT6H17M           False
# 4                  OAK                ATL       PT14H12M           False
# ...                ...                ...            ...             ...
# 999995             DEN                LAX        PT4H33M           False
# 999996             DEN                LAX       PT13H39M           False
# 999997             DEN                LGA        PT3H50M           False
# 999998             DEN                LGA        PT3H51M           False
# 999999             DEN                LGA        PT7H34M           False
#
#         isRefundable  isNonStop  totalFare  ...  \
# 0              False      False     103.98  ...
# 1              False      False     216.58  ...
# 2              False      False     216.58  ...
# 3              False      False     237.58  ...
# 4              False      False     307.21  ...
# ...              ...        ...        ...  ...
# 999995         False      False     470.60  ...
# 999996         False      False     520.11  ...
# 999997         False       True     173.60  ...
# 999998         False       True     173.60  ...
# 999999         False      False     180.58  ...
#
#            segmentsArrivalTimeEpochSeconds  \
# 0                   1653107460||1653126600
# 1                   1653067080||1653084660
# 2                   1653056820||1653084660
# 3                   1653110940||1653127980
# 4                   1653115560||1653159180
# ...                                    ...
# 999995              1656557160||1656567420
# 999996  1656518700||1656541800||1656563340
# 999997                          1656532500
# 999998                          1656547440
# 999999              1656517980||1656531240
#
#                                    segmentsArrivalTimeRaw  \
# 0       2022-05-20T22:31:00.000-06:00||2022-05-21T05:5...
# 1       2022-05-20T10:18:00.000-07:00||2022-05-20T18:1...
# 2       2022-05-20T07:27:00.000-07:00||2022-05-20T18:1...
# 3       2022-05-20T22:29:00.000-07:00||2022-05-21T06:1...
# 4       2022-05-20T23:46:00.000-07:00||2022-05-21T14:5...
# ...                                                   ...
# 999995  2022-06-29T20:46:00.000-06:00||2022-06-29T22:3...
# 999996  2022-06-29T10:05:00.000-06:00||2022-06-29T15:3...
# 999997                      2022-06-29T15:55:00.000-04:00
# 999998                      2022-06-29T20:04:00.000-04:00
# 999999  2022-06-29T11:53:00.000-04:00||2022-06-29T15:3...
#
#        segmentsArrivalAirportCode segmentsDepartureAirportCode  \
# 0                        DEN||ATL                     OAK||DEN
# 1                        LAX||ATL                     OAK||LAX
# 2                        LAX||ATL                     OAK||LAX
# 3                        LAS||ATL                     OAK||LAS
# 4                        SEA||ATL                     OAK||SEA
# ...                           ...                          ...
# 999995                   SLC||LAX                     DEN||SLC
# 999996              CEZ||PHX||ONT                DEN||CEZ||PHX
# 999997                        LGA                          DEN
# 999998                        LGA                          DEN
# 999999                   FLL||LGA                     DEN||FLL
#
#                                   segmentsAirlineName segmentsAirlineCode  \
# 0                Frontier Airlines||Frontier Airlines              F9||F9
# 1                    Spirit Airlines||Spirit Airlines              NK||NK
# 2                    Spirit Airlines||Spirit Airlines              NK||NK
# 3                    Spirit Airlines||Spirit Airlines              NK||NK
# 4                    Alaska Airlines||Alaska Airlines              AS||AS
# ...                                               ...                 ...
# 999995                        United||Alaska Airlines              UA||AS
# 999996  Boutique Air||Boutique Air||American Airlines          4B||4B||AA
# 999997                                JetBlue Airways                  B6
# 999998                                JetBlue Airways                  B6
# 999999               Spirit Airlines||Spirit Airlines              NK||NK
#
#                              segmentsEquipmentDescription  \
# 0                                           ||Airbus A320
# 1                       ||AIRBUS INDUSTRIE A320 SHARKLETS
# 2       AIRBUS INDUSTRIE A320 SHARKLETS||AIRBUS INDUST...
# 3            AIRBUS INDUSTRIE A320 SHARKLETS||Airbus A319
# 4                          Boeing 737-900||Boeing 737-900
# ...                                                   ...
# 999995       Embraer 175 (Enhanced Winglets)||Embraer 175
# 999996  Pilatus PC-12||Pilatus PC-12||Canadair Regiona...
# 999997                                        Airbus A320
# 999998                                        Airbus A320
# 999999                  ||AIRBUS INDUSTRIE A321 SHARKLETS
#
#        segmentsDurationInSeconds segmentsDistance    segmentsCabinCode
# 0                    9180||10620        943||1207         coach||coach
# 1                    4920||15600       None||None         coach||coach
# 2                    4920||15600       None||None         coach||coach
# 3                    5580||13980       None||None         coach||coach
# 4                    7500||17580        672||2178         coach||coach
# ...                          ...              ...                  ...
# 999995                6120||7320         380||590         coach||coach
# 999996          4500||5400||4620    265||329||347  coach||coach||coach
# 999997                     13800             1621                coach
# 999998                     13860             1621                coach
# 999999              13980||11100       None||None         coach||coach
#
# [1000000 rows x 23 columns]

# %%
Sample_flights = merged_df.head(100000)

# %%
Sample_flights.to_csv('/Users/thusondube/Downloads/sample_flights.csv')

# %%
distinct_values_counts = {col: merged_df[col].nunique() for col in merged_df.columns}

# %%
for col, values in distinct_values_counts.items():
    print(f"Column '{col}' has distinct values and their counts:\n{values}\n")
# Out:
# Column 'legId' has distinct values and their counts:
# 1721518
#
# Column 'searchDate' has distinct values and their counts:
# 32
#
# Column 'flightDate' has distinct values and their counts:
# 92
#
# Column 'startingAirport' has distinct values and their counts:
# 16
#
# Column 'destinationAirport' has distinct values and their counts:
# 16
#
# Column 'travelDuration' has distinct values and their counts:
# 1836
#
# Column 'isBasicEconomy' has distinct values and their counts:
# 2
#
# Column 'isRefundable' has distinct values and their counts:
# 2
#
# Column 'isNonStop' has distinct values and their counts:
# 2
#
# Column 'totalFare' has distinct values and their counts:
# 36175
#
# Column 'totalTravelDistance' has distinct values and their counts:
# 2643
#
# Column 'segmentsDepartureTimeEpochSeconds' has distinct values and their counts:
# 1273965
#
# Column 'segmentsDepartureTimeRaw' has distinct values and their counts:
# 1374911
#
# Column 'segmentsArrivalTimeEpochSeconds' has distinct values and their counts:
# 1447133
#
# Column 'segmentsArrivalTimeRaw' has distinct values and their counts:
# 1513276
#
# Column 'segmentsArrivalAirportCode' has distinct values and their counts:
# 5986
#
# Column 'segmentsDepartureAirportCode' has distinct values and their counts:
# 5877
#
# Column 'segmentsAirlineName' has distinct values and their counts:
# 118
#
# Column 'segmentsAirlineCode' has distinct values and their counts:
# 118
#
# Column 'segmentsEquipmentDescription' has distinct values and their counts:
# 6882
#
# Column 'segmentsDurationInSeconds' has distinct values and their counts:
# 110976
#
# Column 'segmentsDistance' has distinct values and their counts:
# 12126
#
# Column 'segmentsCabinCode' has distinct values and their counts:
# 52
